# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries

# %%
# %pip install pandas networkx community scikit-learn pyvis ipython-sql

# %%
import networkx as nx
import pandas as pd
import community.community_louvain as community_louvain
from sklearn.preprocessing import MinMaxScaler
from pyvis.network import Network

# %% [markdown]
# # Load Data from Database
# Load data from the SQLite database into a pandas DataFrame using a SQL query. The query selects pairs of artists who have collaborated on tracks, along with the count of their collaborations. The data is filtered based on the popularity of the artists and tracks.

# %%
# Define the filters to apply to the data
artist_popularity = 70 # The minimum popularity of an artist
track_popularity = 50 # The minimum popularity of a track

# %%
# Load the ipython-sql extension
# %load_ext sql

# Connect to the SQLite database
# %sql sqlite:///../db/spotify.sqlite
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT a1.name AS artist_1,
#     a2.name AS artist_2,
#     COUNT(*) AS collaboration_count
# FROM TrackArtist ta1
# JOIN TrackArtist ta2 ON ta1.track_id = ta2.track_id
# AND ta1.artist_id < ta2.artist_id
# JOIN Artist a1 ON ta1.artist_id = a1.id
# JOIN Artist a2 ON ta2.artist_id = a2.id
# JOIN Track ON ta1.track_id = Track.id
# WHERE a1.name IS NOT NULL
# AND a2.name IS NOT NULL
# AND Track.popularity > :track_popularity
# AND a1.popularity > :artist_popularity
# AND a2.popularity > :artist_popularity
# GROUP BY a1.name, a2.name
# ORDER BY collaboration_count DESC
# Out:
#  * sqlite:///../db/spotify.sqlite
# Done.
# [('Metro Boomin', 'Future', 34),
#  ('Dimitri Vegas', 'Dimitri Vegas & Like Mike', 14),
#  ('Gunna', 'Young Thug', 11),
#  ('Travis Scott', 'Young Thug', 11),
#  ('Keinemusik', 'Adam Port', 10),
#  ('League of Legends', 'Arcane', 10),
#  ('Quavo', 'Travis Scott', 10),
#  ('Drake', 'Lil Wayne', 9),
#  ('Kanye West', 'Ty Dolla $ign', 9),
#  ('Travis Scott', 'Future', 9),
#  ('¥$', 'Kanye West', 9),
#  ('¥$', 'Ty Dolla $ign', 9),
#  ('J Balvin', 'Bad Bunny', 8),
#  ('Macklemore', 'Macklemore & Ryan Lewis', 8),
#  ('Metro Boomin', '21 Savage', 8),
#  ('Chance the Rapper', 'Justin Bieber', 7),
#  ('Ellie Goulding', 'Calvin Harris', 7),
#  ('Future', 'The Weeknd', 7),
#  ('Juice WRLD', 'Trippie Redd', 7),
#  ('Travis Scott', 'Metro Boomin', 7),
#  ('A$AP Rocky', 'Playboi Carti', 6),
#  ('A$AP Rocky', 'Tyler, The Creator', 6),
#  ('David Guetta', 'Ava Max', 6),
#  ('Future', 'Drake', 6),
#  ('Tainy', 'Bad Bunny', 6),
#  ('The Weeknd', 'Ariana Grande', 6),
#  ('The Weeknd', 'Lily-Rose Depp', 6),
#  ('Travis Scott', 'Gunna', 6),
#  ('A$AP Rocky', 'ScHoolboy Q', 5),
#  ('Camila Cabello', 'Shawn Mendes', 5),
#  ('DJ Khaled', 'Drake', 5),
#  ('Future', 'Don Toliver', 5),
#  ('Future', 'Young Thug', 5),
#  ('Imagine Dragons', 'Arcane', 5),
#  ('Imagine Dragons', 'JID', 5),
#  ('Justin Bieber', 'Don Toliver', 5),
#  ('Kygo', 'OneRepublic', 5),
#  ('Lana Del Rey', 'The Weeknd', 5),
#  ('Lil Durk', 'Lil Baby', 5),
#  ('Metro Boomin', 'A$AP Rocky', 5),
#  ('Metro Boomin', 'Don Toliver', 5),
#  ('Metro Boomin', 'The Weeknd', 5),
#  ('Nicki Minaj', 'Lil Wayne', 5),
#  ('Quavo', 'Justin Bieber', 5),
#  ('Sia', 'Diplo', 5),
#  ('Tainy', 'J Balvin', 5),
#  ('Tainy', 'Rauw Alejandro', 5),
#  ('Travis Scott', '21 Savage', 5),
#  ('Travis Scott', 'The Weeknd', 5),
#  ('Alphaville', 'Ava Max', 4),
#  ('Alphaville', 'David Guetta', 4),
#  ('Arcane', 'JID', 4),
#  ('Arcángel', 'Bad Bunny', 4),
#  ('Big Sean', 'Justin Bieber', 4),
#  ('Camila Cabello', 'Ed Sheeran', 4),
#  ('Charli xcx', 'Troye Sivan', 4),
#  ('DJ Khaled', 'Justin Bieber', 4),
#  ('DJ Khaled', 'Rick Ross', 4),
#  ('David Guetta', 'Bebe Rexha', 4),
#  ('David Guetta', 'Sia', 4),
#  ('Diplo', 'Skrillex', 4),
#  ('Don Toliver', 'Lil Uzi Vert', 4),
#  ('Farruko', 'Myke Towers', 4),
#  ('Future', 'Juice WRLD', 4),
#  ('Future', 'Justin Bieber', 4),
#  ('Halsey', 'BTS', 4),
#  ('JAY-Z', 'Linkin Park', 4),
#  ('JAY-Z', 'Rihanna', 4),
#  ('Juice WRLD', 'Young Thug', 4),
#  ('Justin Bieber', 'Ludacris', 4),
#  ('Kendrick Lamar', 'SZA', 4),
#  ('Kid Cudi', 'Justin Timberlake', 4),
#  ('Kid Cudi', 'Troye Sivan', 4),
#  ('Labrinth', 'Diplo', 4),
#  ('Labrinth', 'Sia', 4),
#  ('Lil Uzi Vert', 'Playboi Carti', 4),
#  ('Lil Wayne', 'Chris Brown', 4),
#  ('Lily-Rose Depp', 'JENNIE', 4),
#  ('Luis Fonsi', 'Daddy Yankee', 4),
#  ('Mambo Kingz', 'DJ Luian', 4),
#  ('Metro Boomin', 'Offset', 4),
#  ('Nicki Minaj', 'Ariana Grande', 4),
#  ('Nicki Minaj', 'Chris Brown', 4),
#  ('Nicki Minaj', 'David Guetta', 4),
#  ('Nicki Minaj', 'Drake', 4),
#  ('Quavo', 'Offset', 4),
#  ('Rick Ross', 'Drake', 4),
#  ('Sam Smith', 'Calvin Harris', 4),
#  ('Tainy', 'Alvaro Diaz', 4),
#  ('Taylor Swift', 'Ed Sheeran', 4),
#  ('The Weeknd', 'Daft Punk', 4),
#  ('The Weeknd', 'JENNIE', 4),
#  ('The Weeknd', 'Playboi Carti', 4),
#  ('Travis Scott', 'Kid Cudi', 4),
#  ('Travis Scott', 'SZA', 4),
#  ('Ñengo Flow', 'Anuel AA', 4),
#  ('21 Savage', 'Offset', 3),
#  ('A$AP Rocky', 'Frank Ocean', 3),
#  ('A$AP Rocky', 'Juicy J', 3),
#  ('Anuel AA', 'Bryant Myers', 3),
#  ('Anuel AA', 'Farruko', 3),
#  ('Bad Bunny', 'Bryant Myers', 3),
#  ('Bad Bunny', 'Dua Lipa', 3),
#  ('DJ Khaled', 'Chance the Rapper', 3),
#  ('DJ Khaled', 'Future', 3),
#  ('DJ Khaled', 'Lil Wayne', 3),
#  ('DJ Khaled', 'Quavo', 3),
#  ('DJ Snake', 'Major Lazer', 3),
#  ('DaBaby', 'Dua Lipa', 3),
#  ('David Guetta', 'Martin Garrix', 3),
#  ('Doja Cat', 'Ariana Grande', 3),
#  ('Drake', 'Chris Brown', 3),
#  ('Drake', 'Rihanna', 3),
#  ('Drake', 'Young Thug', 3),
#  ('Dua Lipa', 'Calvin Harris', 3),
#  ('Elton John', 'Dua Lipa', 3),
#  ('Farruko', 'Bad Bunny', 3),
#  ('Future', 'Chris Brown', 3),
#  ('Future', 'Lil Baby', 3),
#  ('Future', 'Playboi Carti', 3),
#  ('Halsey', 'Khalid', 3),
#  ('Halsey', 'benny blanco', 3),
#  ('J Balvin', 'Dua Lipa', 3),
#  ('JAY-Z', 'Kanye West', 3),
#  ('Juanes', 'Morat', 3),
#  ('Juice WRLD', 'Marshmello', 3),
#  ('Juice WRLD', 'benny blanco', 3),
#  ('Justin Bieber', 'The Kid LAROI', 3),
#  ('Justin Timberlake', 'Camila Cabello', 3),
#  ('Justin Timberlake', 'Troye Sivan', 3),
#  ('Khalid', 'Disclosure', 3),
#  ('Kid Cudi', 'Camila Cabello', 3),
#  ('Kygo', 'Imagine Dragons', 3),
#  ('League of Legends', 'Imagine Dragons', 3),
#  ('MEDUZA', 'Elley Duhé', 3),
#  ('Marshmello', 'Khalid', 3),
#  ('Megan Thee Stallion', 'GloRilla', 3),
#  ('Nicki Minaj', 'Ice Spice', 3),
#  ('Nicki Minaj', 'Rick Ross', 3),
#  ('Nicky Jam', 'J Balvin', 3),
#  ('Noah Kahan', 'Gracie Abrams', 3),
#  ('Ozuna', 'Anuel AA', 3),
#  ('Ozuna', 'DJ Snake', 3),
#  ('Pharrell Williams', 'Daft Punk', 3),
#  ('Quavo', 'Chance the Rapper', 3),
#  ('Quavo', 'Lil Uzi Vert', 3),
#  ('RAYE', 'D-Block Europe', 3),
#  ('Rick Ross', 'JAY-Z', 3),
#  ('Rick Ross', 'Lil Wayne', 3),
#  ('Rihanna', 'Calvin Harris', 3),
#  ('Sean Paul', 'Sia', 3),
#  ('Selena Gomez', 'DJ Snake', 3),
#  ('Tainy', 'Dua Lipa', 3),
#  ('Tainy', 'Feid', 3),
#  ('Taylor Swift', 'Bon Iver', 3),
#  ('Taylor Swift', 'Post Malone', 3),
#  ('The Weeknd', 'Doja Cat', 3),
#  ('The Weeknd', 'Drake', 3),
#  ('The Weeknd', 'Gesaffelstein', 3),
#  ('The Weeknd', 'Swedish House Mafia', 3),
#  ('Topic', 'HUGEL', 3),
#  ('Travis Scott', '2 Chainz', 3),
#  ('Travis Scott', 'Don Toliver', 3),
#  ('Travis Scott', 'Justin Bieber', 3),
#  ('Travis Scott', 'Lil Baby', 3),
#  ('Travis Scott', 'Offset', 3),
#  ('Tyler, The Creator', 'Lil Wayne', 3),
#  ('Wizkid', 'Tems', 3),
#  ('benny blanco', 'Khalid', 3),
#  ('Ñengo Flow', 'Bad Bunny', 3),
#  ('(G)I-DLE', 'League of Legends', 2),
#  ('2 Chainz', 'Lil Wayne', 2),
#  ('21 Savage', 'The Weeknd', 2),
#  ('50 Cent', 'Eminem', 2),
#  ('6LACK', 'Khalid', 2),
#  ('A$AP Rocky', 'Denzel Curry', 2),
#  ('A$AP Rocky', 'Future', 2),
#  ('A$AP Rocky', 'Kendrick Lamar', 2),
#  ('A$AP Rocky', 'Lil Uzi Vert', 2),
#  ('A$AP Rocky', 'Skepta', 2),
#  ('A$AP Rocky', 'Young Thug', 2),
#  ('Anne-Marie', 'Clean Bandit', 2),
#  ('Anuel AA', 'Bad Bunny', 2),
#  ('Anuel AA', 'DJ Luian', 2),
#  ('Anuel AA', 'Eladio Carrion', 2),
#  ('Anuel AA', 'JHAYCO', 2),
#  ('Anuel AA', 'Mambo Kingz', 2),
#  ('Anuel AA', 'Myke Towers', 2),
#  ('Anuel AA', 'Wisin', 2),
#  ('Arcane', 'Pomme', 2),
#  ('Arcane', 'Stromae', 2),
#  ('Arcane', 'd4vd', 2),
#  ('Ariana Grande', 'Ty Dolla $ign', 2),
#  ('Ava Max', 'Alan Walker', 2),
#  ('BTS', 'Steve Aoki', 2),
#  ('Bad Bunny', 'Almighty', 2),
#  ('Bad Bunny', 'DJ Luian', 2),
#  ('Bad Bunny', 'Sech', 2),
#  ('Bastille', 'Lost Frequencies', 2),
#  ('Big Sean', 'Calvin Harris', 2),
#  ('Big Sean', 'Jhené Aiko', 2),
#  ('Big Sean', 'Nicki Minaj', 2),
#  ('Bon Iver', 'Kanye West', 2),
#  ('Bruno Mars', 'B.o.B', 2),
#  ('Bruno Mars', 'Chris Stapleton', 2),
#  ('Bruno Mars', 'Ed Sheeran', 2),
#  ('Bruno Mars', 'Lady Gaga', 2),
#  ('Burna Boy', 'Coldplay', 2),
#  ('Burna Boy', 'TINI', 2),
#  ('Calum Scott', 'Lost Frequencies', 2),
#  ('Camila Cabello', 'Alejandro Sanz', 2),
#  ('Camila Cabello', 'Playboi Carti', 2),
#  ('Camilo', 'Carin Leon', 2),
#  ('Cardi B', 'Camila Cabello', 2),
#  ('Cardi B', 'DJ Snake', 2),
#  ('Cardi B', 'Ed Sheeran', 2),
#  ('Central Cee', 'D-Block Europe', 2),
#  ('Chance the Rapper', 'Ed Sheeran', 2),
#  ('Chance the Rapper', 'Lil Wayne', 2),
#  ('Charli xcx', 'Ariana Grande', 2),
#  ('Charli xcx', 'Billie Eilish', 2),
#  ('Chris Stapleton', 'Ed Sheeran', 2),
#  ('Coldplay', 'TINI', 2),
#  ('Cynthia Erivo', 'Ariana Grande', 2),
#  ('DJ Khaled', 'Lil Baby', 2),
#  ('DJ Khaled', 'Nicki Minaj', 2),
#  ('DJ Khaled', 'Post Malone', 2),
#  ('DJ Khaled', 'SZA', 2),
#  ('DJ Khaled', 'Travis Scott', 2),
#  ('DaBaby', 'Lil Yachty', 2),
#  ('Daniel Caesar', 'Tyler, The Creator', 2),
#  ('Darell', 'Farruko', 2),
#  ('David Bowie', 'Queen', 2),
#  ('David Guetta', 'AFROJACK', 2),
#  ('David Guetta', 'Anne-Marie', 2),
#  ('David Guetta', 'Dimitri Vegas', 2),
#  ('David Guetta', 'Dimitri Vegas & Like Mike', 2),
#  ('David Guetta', 'J Balvin', 2),
#  ('David Guetta', 'Justin Bieber', 2),
#  ('David Guetta', 'Little Mix', 2),
#  ('David Guetta', 'OneRepublic', 2),
#  ('David Guetta', 'Rihanna', 2),
#  ('David Guetta', 'Robin Schulz', 2),
#  ('Dei V', 'Bryant Myers', 2),
#  ('Diplo', 'Polo G', 2),
#  ('Diplo', 'Trippie Redd', 2),
#  ('Doechii', 'Katy Perry', 2),
#  ('Doja Cat', 'SZA', 2),
#  ('Don Toliver', 'SZA', 2),
#  ('Drake', 'DaBaby', 2),
#  ('Drake', 'Lil Yachty', 2),
#  ('Duki', 'Morat', 2),
#  ('Elley Duhé', 'Lost Frequencies', 2),
#  ('Feid', 'Alvaro Diaz', 2),
#  ('Feid', 'Morat', 2),
#  ('Flo Rida', 'David Guetta', 2),
#  ('Flo Rida', 'Kesha', 2),
#  ('Florence + The Machine', 'Calvin Harris', 2),
#  ('Frank Ocean', 'Calvin Harris', 2),
#  ('Frank Ocean', 'Lil Uzi Vert', 2),
#  ('Frank Ocean', 'Migos', 2),
#  ('Frank Ocean', 'Playboi Carti', 2),
#  ('Frank Ocean', 'Tyler, The Creator', 2),
#  ('Fred again..', 'Skrillex', 2),
#  ('Future', 'Calvin Harris', 2),
#  ('Future', 'Fred again..', 2),
#  ('Future', 'Gunna', 2),
#  ('Future', 'Khalid', 2),
#  ('Future', 'Lil Durk', 2),
#  ('Future', 'Lil Uzi Vert', 2),
#  ('Future', 'Lil Yachty', 2),
#  ('Future', 'Rick Ross', 2),
#  ('Future', 'SZA', 2),
#  ('Future', 'Swedish House Mafia', 2),
#  ('Future', 'Ty Dolla $ign', 2),
#  ('G-Eazy', 'Halsey', 2),
#  ('Gunna', 'Don Toliver', 2),
#  ('Gunna', 'Lil Baby', 2),
#  ('Gunna', 'Roddy Ricch', 2),
#  ('H.E.R.', 'Chris Brown', 2),
#  ('Halsey', 'Juice WRLD', 2),
#  ('Halsey', 'The Chainsmokers', 2),
#  ('Hozier', 'Noah Kahan', 2),
#  ('Imagine Dragons', 'Lil Wayne', 2),
#  ('J Balvin', 'Anitta', 2),
#  ('J Balvin', 'Bebe Rexha', 2),
#  ('J Balvin', 'Chencho Corleone', 2),
#  ('J Balvin', 'KAROL G', 2),
#  ('JHAYCO', 'Myke Towers', 2),
#  ('JVKE', 'Charlie Puth', 2),
#  ('JVKE', 'Jimin', 2),
#  ('Jack Harlow', 'Lil Nas X', 2),
#  ('Jess Glynne', 'Clean Bandit', 2),
#  ('Jessie Murph', 'Diplo', 2),
#  ('Jessie Murph', 'Polo G', 2),
#  ('Jimin', 'Charlie Puth', 2),
#  ('John Legend', 'Meghan Trainor', 2),
#  ('Juice WRLD', 'Polo G', 2),
#  ('Julia Michaels', 'Kygo', 2),
#  ('Julieta Venegas', 'Bad Bunny', 2),
#  ('Justin Bieber', 'Chris Brown', 2),
#  ('Justin Bieber', 'Daddy Yankee', 2),
#  ('Justin Bieber', 'Drake', 2),
#  ('Justin Bieber', 'Ed Sheeran', 2),
#  ('Justin Bieber', 'J Balvin', 2),
#  ('Justin Bieber', 'Luis Fonsi', 2),
#  ('Justin Bieber', 'Omah Lay', 2),
#  ('Justin Bieber', 'Post Malone', 2),
#  ('Justin Bieber', 'Shawn Mendes', 2),
#  ('Justin Bieber', 'Skrillex', 2),
#  ('Justin Bieber', 'Tems', 2),
#  ('Justin Bieber', 'USHER', 2),
#  ('Justin Bieber', 'Wizkid', 2),
#  ('Justin Bieber', 'benny blanco', 2),
#  ('Kane Brown', 'Marshmello', 2),
#  ('Kanye West', 'John Legend', 2),
#  ('Katy Perry', 'Snoop Dogg', 2),
#  ('Kehlani', 'Justin Bieber', 2),
#  ('Kelly Clarkson', 'Ariana Grande', 2),
#  ('Kendrick Lamar', 'Drake', 2),
#  ('Khalid', 'Calvin Harris', 2),
#  ('Kid Cudi', 'A$AP Rocky', 2),
#  ('Kygo', 'Alan Walker', 2),
#  ('Kygo', 'Ava Max', 2),
#  ('Kygo', 'Calum Scott', 2),
#  ('Kygo', 'Dean Lewis', 2),
#  ('Kygo', 'Miguel', 2),
#  ('Kygo', 'Nile Rodgers', 2),
#  ('Kygo', 'Whitney Houston', 2),
#  ('Kylie Minogue', 'Diplo', 2),
#  ('Lady Gaga', 'Ariana Grande', 2),
#  ('Lady Gaga', 'Beyoncé', 2),
#  ('Lana Del Rey', 'A$AP Rocky', 2),
#  ('Lana Del Rey', 'Quavo', 2),
#  ('Lana Del Rey', 'Taylor Swift', 2),
#  ('League of Legends', 'JID', 2),
#  ('Lil Wayne', 'Kanye West', 2),
#  ('Lil Wayne', 'Tyga', 2),
#  ('Lizzy McAlpine', 'Noah Kahan', 2),
#  ('Lorde', 'Charli xcx', 2),
#  ('Luis Fonsi', 'Clean Bandit', 2),
#  ('Luis Fonsi', 'MARINA', 2),
#  ('MARINA', 'Clean Bandit', 2),
#  ('MEDUZA', 'HUGEL', 2),
#  ('Mac Miller', 'Ariana Grande', 2),
#  ('Macklemore', 'Jess Glynne', 2),
#  ('Macklemore', 'Ray Dalton', 2),
#  ('Mambo Kingz', 'Bad Bunny', 2),
#  ('Maria Becerra', 'J Balvin', 2),
#  ('Mariah Carey', 'Ariana Grande', 2),
#  ('Mark Ronson', 'Miley Cyrus', 2),
#  ('Maroon 5', 'Cardi B', 2),
#  ('Maroon 5', 'Christina Aguilera', 2),
#  ('Marshmello', 'Jonas Brothers', 2),
#  ('Marshmello', 'Polo G', 2),
#  ('Meek Mill', 'Lil Baby', 2),
#  ('Megan Thee Stallion', 'Beyoncé', 2),
#  ('Megan Thee Stallion', 'Cardi B', 2),
#  ('Megan Thee Stallion', 'DaBaby', 2),
#  ('Megan Thee Stallion', 'Dua Lipa', 2),
#  ('Megan Thee Stallion', 'RM', 2),
#  ('Metro Boomin', 'Lil Uzi Vert', 2),
#  ('Metro Boomin', 'Swae Lee', 2),
#  ('Metro Boomin', 'Young Thug', 2),
#  ('Migos', 'Calvin Harris', 2),
#  ('Miguel', 'J. Cole', 2),
#  ('Miley Cyrus', 'Dua Lipa', 2),
#  ('Miley Cyrus', 'French Montana', 2),
#  ('Morat', 'Aitana', 2),
#  ('Mustard', 'Roddy Ricch', 2),
#  ('Mustard', 'Wiz Khalifa', 2),
#  ('NATTI NATASHA', 'Daddy Yankee', 2),
#  ('NATTI NATASHA', 'Dimitri Vegas', 2),
#  ('NATTI NATASHA', 'Dimitri Vegas & Like Mike', 2),
#  ('Niall Horan', 'Anne-Marie', 2),
#  ('Nicki Minaj', 'Beyoncé', 2),
#  ('Nicki Minaj', 'Future', 2),
#  ('Nicki Minaj', 'Jeremih', 2),
#  ('Nicki Minaj', 'Juice WRLD', 2),
#  ('Nicki Minaj', 'Justin Bieber', 2),
#  ('Nicki Minaj', 'Kanye West', 2),
#  ('Nicky Jam', 'KAROL G', 2),
#  ('Nile Rodgers', 'Daft Punk', 2),
#  ('Noah Kahan', 'Kacey Musgraves', 2),
#  ('Noah Kahan', 'Sam Fender', 2),
#  ('Olivia Rodrigo', 'Disney', 2),
#  ('Ovy On The Drums', 'KAROL G', 2),
#  ('Ozuna', 'Cardi B', 2),
#  ('Ozuna', 'J Balvin', 2),
#  ('Pharrell Williams', 'Calvin Harris', 2),
#  ('Pharrell Williams', 'Nile Rodgers', 2),
#  ('Pharrell Williams', 'Tyler, The Creator', 2),
#  ('Playboi Carti', 'Lil Yachty', 2),
#  ('Playboi Carti', 'Madonna', 2),
#  ('Polo G', 'Trippie Redd', 2),
#  ('Pop Smoke', 'Lil Tjay', 2),
#  ('Post Malone', 'DaBaby', 2),
#  ('Post Malone', 'Lil Baby', 2),
#  ('Post Malone', 'Noah Kahan', 2),
#  ('Post Malone', 'SZA', 2),
#  ('Post Malone', 'Young Thug', 2),
#  ('Quavo', 'A$AP Rocky', 2),
#  ('Quavo', 'Camila Cabello', 2),
#  ('Quavo', 'Frank Ocean', 2),
#  ('Quavo', 'Playboi Carti', 2),
#  ('Rauw Alejandro', 'Alvaro Diaz', 2),
#  ('Rauw Alejandro', 'Anuel AA', 2),
#  ('Rauw Alejandro', 'Bad Bunny', 2),
#  ('Reik', 'Maluma', 2),
#  ('Rick Ross', 'Chris Brown', 2),
#  ('Rick Ross', 'Kanye West', 2),
#  ('Sam Smith', 'Disclosure', 2),
#  ('Sam Smith', 'Kim Petras', 2),
#  ('Sean Paul', 'Beyoncé', 2),
#  ('Sean Paul', 'Dua Lipa', 2),
#  ('Sebastian Yatra', 'Aitana', 2),
#  ('Sebastian Yatra', 'Manuel Turizo', 2),
#  ('Sebastian Yatra', 'Morat', 2),
#  ('Sebastian Yatra', 'Pablo Alborán', 2),
#  ('Sebastian Yatra', 'Reik', 2),
#  ('Sebastian Yatra', 'TINI', 2),
#  ('Selena Gomez', 'A$AP Rocky', 2),
#  ('Selena Gomez', 'Cardi B', 2),
#  ('Selena Gomez', 'Kygo', 2),
#  ('Selena Gomez', 'Ozuna', 2),
#  ('Sia', 'ZAYN', 2),
#  ('Skepta', 'Wizkid', 2),
#  ('Stromae', 'Pomme', 2),
#  ('Swedish House Mafia', 'Fred again..', 2),
#  ('Tainy', 'JHAYCO', 2),
#  ('Tainy', 'Julieta Venegas', 2),
#  ('Tainy', 'Sech', 2),
#  ('Tainy', 'Young Miko', 2),
#  ('Taylor Swift', 'Florence + The Machine', 2),
#  ('The Kid LAROI', 'Juice WRLD', 2),
#  ('The Kid LAROI', 'Marshmello', 2),
#  ('The Kid LAROI', 'Polo G', 2),
#  ('The Lumineers', 'Noah Kahan', 2),
#  ('The Weeknd', 'Anitta', 2),
#  ('The Weeknd', 'Bad Bunny', 2),
#  ('The Weeknd', 'Juice WRLD', 2),
#  ('The Weeknd', 'Lil Baby', 2),
#  ('The Weeknd', 'Madonna', 2),
#  ('Travis Scott', 'Bad Bunny', 2),
#  ('Travis Scott', 'Drake', 2),
#  ('Travis Scott', 'Kanye West', 2),
#  ('Travis Scott', 'Lil Uzi Vert', 2),
#  ('Travis Scott', 'Pharrell Williams', 2),
#  ('Travis Scott', 'Playboi Carti', 2),
#  ('Travis Scott', 'Post Malone', 2),
#  ('Travis Scott', 'Swae Lee', 2),
#  ('Troye Sivan', 'Ariana Grande', 2),
#  ('Troye Sivan', 'Camila Cabello', 2),
#  ('Twenty One Pilots', 'Arcane', 2),
#  ('Tyga', 'Chris Brown', 2),
#  ('Tyga', 'Doja Cat', 2),
#  ('Tyler, The Creator', 'Rex Orange County', 2),
#  ('Tyler, The Creator', 'Steve Lacy', 2),
#  ('Wisin', 'Myke Towers', 2),
#  ('Wiz Khalifa', 'Charlie Puth', 2),
#  ('Wiz Khalifa', 'Juicy J', 2),
#  ('Wiz Khalifa', 'Logic', 2),
#  ('Wiz Khalifa', 'Miley Cyrus', 2),
#  ('Wiz Khalifa', 'The Weeknd', 2),
#  ('Wiz Khalifa', 'Ty Dolla $ign', 2),
#  ('Wizkid', 'Don Toliver', 2),
#  ('YG', 'Drake', 2),
#  ('YG', 'Nicki Minaj', 2),
#  ('YNW Melly', 'Juice WRLD', 2),
#  ('Young Thug', 'Lil Baby', 2),
#  ('Zach Bryan', 'Bon Iver', 2),
#  ('blackbear', 'mgk', 2),
#  ('girl in red', 'Sabrina Carpenter', 2),
#  ('will.i.am', 'Justin Bieber', 2),
#  ('(G)I-DLE', 'Madison Beer', 1),
#  ('2 Chainz', '21 Savage', 1),
#  ('2 Chainz', 'Chance the Rapper', 1),
#  ('2 Chainz', 'Chris Brown', 1),
#  ('2 Chainz', 'Denzel Curry', 1),
#  ('2 Chainz', 'Don Toliver', 1),
#  ('2 Chainz', 'Drake', 1),
#  ('2 Chainz', 'Future', 1),
#  ('2 Chainz', 'Jhené Aiko', 1),
#  ('2 Chainz', 'Juicy J', 1),
#  ('2 Chainz', 'Kendrick Lamar', 1),
#  ('2 Chainz', 'Lil Jon', 1),
#  ('2 Chainz', 'Offset', 1),
#  ('2 Chainz', 'Post Malone', 1),
#  ('2 Chainz', 'Rick Ross', 1),
#  ('2 Chainz', 'ScHoolboy Q', 1),
#  ('2 Chainz', 'T.I.', 1),
#  ('2 Chainz', 'Ty Dolla $ign', 1),
#  ('21 Savage', 'Childish Gambino', 1),
#  ('21 Savage', 'Doja Cat', 1),
#  ('21 Savage', 'Don Toliver', 1),
#  ('21 Savage', 'French Montana', 1),
#  ('21 Savage', 'Gunna', 1),
#  ('21 Savage', 'Justin Bieber', 1),
#  ('21 Savage', 'Kodak Black', 1),
#  ('21 Savage', 'Pharrell Williams', 1),
#  ('21 Savage', 'Roddy Ricch', 1),
#  ('21 Savage', 'ScHoolboy Q', 1),
#  ('21 Savage', 'Tyler, The Creator', 1),
#  ('21 Savage', 'Young Thug', 1),
#  ('5 Seconds of Summer', 'The Chainsmokers', 1),
#  ('50 Cent', 'Ed Sheeran', 1),
#  ('6LACK', 'Jhené Aiko', 1),
#  ('6LACK', 'Lil Baby', 1),
#  ('6LACK', 'Summer Walker', 1),
#  ('6LACK', 'Ty Dolla $ign', 1),
#  ('A Boogie Wit da Hoodie', 'Fetty Wap', 1),
#  ('A Boogie Wit da Hoodie', 'Juice WRLD', 1),
#  ('A Boogie Wit da Hoodie', 'Khalid', 1),
#  ('A Boogie Wit da Hoodie', 'Lil Tecca', 1),
#  ('A Boogie Wit da Hoodie', 'Nemzzz', 1),
#  ('A Boogie Wit da Hoodie', 'Playboi Carti', 1),
#  ('A Boogie Wit da Hoodie', 'Roddy Ricch', 1),
#  ('A Boogie Wit da Hoodie', 'Summer Walker', 1),
#  ('A$AP Rocky', '2 Chainz', 1),
#  ('A$AP Rocky', '21 Savage', 1),
#  ('A$AP Rocky', 'Anderson .Paak', 1),
#  ('A$AP Rocky', 'BONES', 1),
#  ('A$AP Rocky', 'Brent Faiyaz', 1),
#  ('A$AP Rocky', 'Cardi B', 1),
#  ('A$AP Rocky', 'Drake', 1),
#  ('A$AP Rocky', 'FKA twigs', 1),
#  ('A$AP Rocky', 'French Montana', 1),
#  ('A$AP Rocky', 'Imogen Heap', 1),
#  ('A$AP Rocky', 'J. Cole', 1),
#  ('A$AP Rocky', 'Joey Bada$$', 1),
#  ('A$AP Rocky', 'Kanye West', 1),
#  ('A$AP Rocky', 'Lil Wayne', 1),
#  ('A$AP Rocky', 'Lil Yachty', 1),
#  ('A$AP Rocky', 'Mark Ronson', 1),
#  ('A$AP Rocky', 'Miguel', 1),
#  ('A$AP Rocky', 'Pharrell Williams', 1),
#  ('A$AP Rocky', 'Post Malone', 1),
#  ('A$AP Rocky', 'Rod Stewart', 1),
#  ('A$AP Rocky', 'Skrillex', 1),
#  ('A$AP Rocky', 'T.I.', 1),
#  ('A$AP Rocky', 'The Weeknd', 1),
#  ('A.R. Rahman', 'Kylie Minogue', 1),
#  ('AFROJACK', 'Bebe Rexha', 1),
#  ('AURORA', 'Pomme', 1),
#  ('AURORA', 'Tom Odell', 1),
#  ('Adam Port', 'Camila Cabello', 1),
#  ('Adam Port', 'Dua Lipa', 1),
#  ('Akon', 'David Guetta', 1),
#  ('Akon', 'Robin Schulz', 1),
#  ('Akon', 'Snoop Dogg', 1),
#  ('Alejandro Sanz', 'TINI', 1),
#  ('Alessia Cara', 'Alec Benjamin', 1),
#  ('Alessia Cara', 'Khalid', 1),
#  ('Alessia Cara', 'Logic', 1),
#  ('Alesso', 'Calvin Harris', 1),
#  ('Alesso', 'Katy Perry', 1),
#  ('Alesso', 'Marshmello', 1),
#  ('Alesso', 'OneRepublic', 1),
#  ('Alesso', 'Tove Lo', 1),
#  ('Alicia Keys', 'JAY-Z', 1),
#  ('Almighty', 'Bryant Myers', 1),
#  ('Almighty', 'JHAYCO', 1),
#  ('Alok', 'Alan Walker', 1),
#  ('Alok', 'Ana Castela', 1),
#  ('Alok', 'Armin van Buuren', 1),
#  ('Alok', 'Ava Max', 1),
#  ('Alok', 'Ellie Goulding', 1),
#  ('Alok', 'Hungria', 1),
#  ('Alok', 'James Arthur', 1),
#  ('Alok', 'Jess Glynne', 1),
#  ('Alok', 'Khalid', 1),
#  ('Alok', 'MC Hariel', 1),
#  ('Alok', 'MC Ryan SP', 1),
#  ('Alok', 'MEDUZA', 1),
#  ('Alok', 'Marshmello', 1),
#  ('Alok', 'Tate McRae', 1),
#  ('Alok', 'The Chainsmokers', 1),
#  ('Alphaville', 'CYRIL', 1),
#  ('Anne-Marie', 'James Arthur', 1),
#  ('Anne-Marie', 'Marshmello', 1),
#  ('Anne-Marie', 'Sean Paul', 1),
#  ('Anuel AA', 'Almighty', 1),
#  ('Anuel AA', 'Bizarrap', 1),
#  ('Anuel AA', 'Chencho Corleone', 1),
#  ('Anuel AA', 'De La Ghetto', 1),
#  ('Anuel AA', 'Dei V', 1),
#  ('Anuel AA', 'Hades66', 1),
#  ('Anuel AA', 'Jay Wheeler', 1),
#  ('Anuel AA', 'Luar La L', 1),
#  ('Anuel AA', 'Ovy On The Drums', 1),
#  ('Anuel AA', 'Romeo Santos', 1),
#  ('Anuel AA', 'iZaak', 1),
#  ('Arcángel', 'Almighty', 1),
#  ('Arcángel', 'Bryant Myers', 1),
#  ('Arcángel', 'DJ Luian', 1),
#  ('Arcángel', 'Myke Towers', 1),
#  ('Arcángel', 'Sech', 1),
#  ('Ariana Grande', 'Childish Gambino', 1),
#  ('Ariana Grande', 'Demi Lovato', 1),
#  ('Ariana Grande', 'Idina Menzel', 1),
#  ('Ariana Grande', 'Stevie Wonder', 1),
#  ('Armin van Buuren', 'David Guetta', 1),
#  ('Armin van Buuren', 'Dimitri Vegas', 1),
#  ('Armin van Buuren', 'Dimitri Vegas & Like Mike', 1),
#  ('Armin van Buuren', 'Elley Duhé', 1),
#  ('Armin van Buuren', 'Teddy Swims', 1),
#  ('Armin van Buuren', 'W&W', 1),
#  ('Artemas', 'Nessa Barrett', 1),
#  ('Ava Max', 'ENHYPEN', 1),
#  ('Avicii', 'Alan Walker', 1),
#  ('Avicii', 'Felix Jaehn', 1),
#  ('Avicii', 'Kygo', 1),
#  ('Avicii', 'Lenny Kravitz', 1),
#  ('Avicii', 'Skrillex', 1),
#  ('Ayra Starr', 'Coldplay', 1),
#  ('Ayra Starr', 'Khalid', 1),
#  ('B.o.B', 'Ty Dolla $ign', 1),
#  ('BLACKPINK', 'Cardi B', 1),
#  ('BTS', 'Coldplay', 1),
#  ('BTS', 'Juice WRLD', 1),
#  ('BTS', 'Lauv', 1),
#  ('BTS', 'Sia', 1),
#  ('Bad Bunny', 'Cazzu', 1),
#  ('Bad Bunny', 'Diplo', 1),
#  ('Bad Bunny', 'Grupo Frontera', 1),
#  ('Bad Bunny', 'JHAYCO', 1),
#  ('Bad Bunny', 'Marc Anthony', 1),
#  ('Bad Bunny', 'ROSALÍA', 1),
#  ('Bebe Rexha', 'The Chainsmokers', 1),
#  ('Bebe Rexha', 'Ty Dolla $ign', 1),
#  ('Bebe Rexha', 'mgk', 1),
#  ('Becky G', 'Bad Bunny', 1),
#  ('Beyoncé', 'Eminem', 1),
#  ('Beyoncé', 'Major Lazer', 1),
#  ('Big Sean', '2 Chainz', 1),
#  ('Big Sean', 'A$AP Rocky', 1),
#  ('Big Sean', 'Ariana Grande', 1),
#  ('Big Sean', 'Chris Brown', 1),
#  ('Big Sean', 'Drake', 1),
#  ('Big Sean', 'Gunna', 1),
#  ('Big Sean', 'John Legend', 1),
#  ('Big Sean', 'Kanye West', 1),
#  ('Big Sean', 'Katy Perry', 1),
#  ('Big Sean', 'Lil Wayne', 1),
#  ('Big Sean', 'Logic', 1),
#  ('Big Sean', 'Pharrell Williams', 1),
#  ('Big Sean', 'Playboi Carti', 1),
#  ('Big Sean', 'Post Malone', 1),
#  ('Big Sean', 'The 1975', 1),
#  ('Billie Eilish', 'ROSALÍA', 1),
#  ('Black Eyed Peas', 'Tiësto', 1),
#  ('Blessd', 'Anuel AA', 1),
#  ('Blessd', 'Ovy On The Drums', 1),
#  ('BoyWithUke', 'blackbear', 1),
#  ('Brent Faiyaz', 'Baby Keem', 1),
#  ('Brent Faiyaz', 'Don Toliver', 1),
#  ('Brent Faiyaz', 'Juice WRLD', 1),
#  ('Brent Faiyaz', 'Marshmello', 1),
#  ('Brent Faiyaz', 'Tyler, The Creator', 1),
#  ('Bring Me The Horizon', 'AURORA', 1),
#  ('Bring Me The Horizon', 'Lil Uzi Vert', 1),
#  ('Bring Me The Horizon', 'blackbear', 1),
#  ('Britney Spears', 'Elton John', 1),
#  ('Britney Spears', 'Madonna', 1),
#  ('Britney Spears', 'Rihanna', 1),
#  ('Bruno Mars', 'Alan Walker', 1),
#  ('Bruno Mars', 'Cardi B', 1),
#  ('Bruno Mars', 'David Guetta', 1),
#  ('Bruno Mars', 'Lil Wayne', 1),
#  ('Bruno Mars', 'Mark Ronson', 1),
#  ('Bruno Mars', 'R3HAB', 1),
#  ('Bryant Myers', 'Sech', 1),
#  ('Bryson Tiller', 'Jack Harlow', 1),
#  ('Bryson Tiller', 'Rihanna', 1),
#  ('Brytiago', 'Almighty', 1),
#  ('Brytiago', 'Arcángel', 1),
#  ('Brytiago', 'Bad Bunny', 1),
#  ('Brytiago', 'Bryant Myers', 1),
#  ('Brytiago', 'DJ Luian', 1),
#  ('Brytiago', 'Mambo Kingz', 1),
#  ('Brytiago', 'Noriel', 1),
#  ('CYRIL', 'Ava Max', 1),
#  ('CYRIL', 'David Guetta', 1),
#  ('CYRIL', 'Robin Schulz', 1),
#  ('Calvin Harris', 'SZA', 1),
#  ('Camila Cabello', 'DaBaby', 1),
#  ('Camila Cabello', 'Lil Nas X', 1),
#  ('Camila Cabello', 'Major Lazer', 1),
#  ('Camila Cabello', 'Young Thug', 1),
#  ('Camilo', 'Alejandro Sanz', 1),
#  ('Camilo', 'Camila Cabello', 1),
#  ('Camilo', 'Farruko', 1),
#  ('Camilo', 'Myke Towers', 1),
#  ('Camilo', 'Yami Safdie', 1),
#  ('Cardi B', 'Kanye West', 1),
#  ('Cardi B', 'Lil Nas X', 1),
#  ('Central Cee', 'Ed Sheeran', 1),
#  ('Chance the Rapper', 'Kanye West', 1),
#  ('Chance the Rapper', 'SZA', 1),
#  ('Charli xcx', 'BTS', 1),
#  ('Charli xcx', 'Kesha', 1),
#  ('Charli xcx', 'Kim Petras', 1),
#  ('Charli xcx', 'Sam Smith', 1),
#  ('Charli xcx', 'Tiësto', 1),
#  ('Charlie Puth', 'Calvin Harris', 1),
#  ('Chencho Corleone', 'Bad Bunny', 1),
#  ('Chencho Corleone', 'Myke Towers', 1),
#  ('Chencho Corleone', 'Wisin', 1),
#  ('Chief Keef', 'Swae Lee', 1),
#  ('Chris Stapleton', 'Dua Lipa', 1),
#  ('Christian Nodal', 'Reik', 1),
#  ('Christina Aguilera', 'Sabrina Carpenter', 1),
#  ('Clean Bandit', 'Demi Lovato', 1),
#  ('Coldplay', 'Rihanna', 1),
#  ('Coldplay', 'The Chainsmokers', 1),
#  ('Cosculluela', 'Anuel AA', 1),
#  ('Cosculluela', 'Sebastian Yatra', 1),
#  ('Cynthia Erivo', 'Idina Menzel', 1),
#  ('DJ Khaled', '21 Savage', 1),
#  ('DJ Khaled', 'Anitta', 1),
#  ('DJ Khaled', 'Bryson Tiller', 1),
#  ('DJ Khaled', 'Chris Brown', 1),
#  ('DJ Khaled', 'DaBaby', 1),
#  ('DJ Khaled', 'Don Toliver', 1),
#  ('DJ Khaled', 'JAY-Z', 1),
#  ('DJ Khaled', 'Jeremih', 1),
#  ('DJ Khaled', 'John Legend', 1),
#  ('DJ Khaled', 'Juice WRLD', 1),
#  ('DJ Khaled', 'Latto', 1),
#  ('DJ Khaled', 'Lil Durk', 1),
#  ('DJ Khaled', 'Mariah Carey', 1),
#  ('DJ Khaled', 'Megan Thee Stallion', 1),
#  ('DJ Khaled', 'Rihanna', 1),
#  ('DJ Luian', 'Almighty', 1),
#  ('DJ Luian', 'Bryant Myers', 1),
#  ('DJ Snake', 'Anitta', 1),
#  ('DJ Snake', 'LISA', 1),
#  ('DJ Snake', 'Lauv', 1),
#  ('DJ Snake', 'Lil Jon', 1),
#  ('DJ Snake', 'Tyga', 1),
#  ('DaBaby', 'Lil Baby', 1),
#  ('DaBaby', 'Lil Wayne', 1),
#  ('DaBaby', 'Roddy Ricch', 1),
#  ('DaBaby', 'Trippie Redd', 1),
#  ('DaBaby', 'Young Thug', 1),
#  ('DaBaby', 'YoungBoy Never Broke Again', 1),
#  ('Daddy Yankee', 'Camila Cabello', 1),
#  ('Daddy Yankee', 'Dimitri Vegas & Like Mike', 1),
#  ('Daddy Yankee', 'Jonas Brothers', 1),
#  ('Daddy Yankee', 'Sech', 1),
#  ('Daddy Yankee', 'Steve Aoki', 1),
#  ('Dalex', 'Bryant Myers', 1),
#  ('Dalex', 'Dei V', 1),
#  ('Dalex', 'Eladio Carrion', 1),
#  ('Dalex', 'Justin Quiles', 1),
#  ('Dalex', 'Lenny Tavárez', 1),
#  ('Dalex', 'Sech', 1),
#  ('Daniel Caesar', 'FKA twigs', 1),
#  ('Daniel Caesar', 'GIVĒON', 1),
#  ('Danny Ocean', 'Alejandro Sanz', 1),
#  ('Danny Ocean', 'Beéle', 1),
#  ('Danny Ocean', 'KAROL G', 1),
#  ('Darell', 'Anuel AA', 1),
#  ('Darell', 'Bad Bunny', 1),
#  ('Dave', 'Ed Sheeran', 1),
#  ('David Guetta', '5 Seconds of Summer', 1),
#  ('David Guetta', 'Alesso', 1),
#  ('David Guetta', 'Anuel AA', 1),
#  ('David Guetta', 'Becky G', 1),
#  ('David Guetta', 'Bryson Tiller', 1),
#  ('David Guetta', 'Chris Brown', 1),
#  ('David Guetta', 'Clean Bandit', 1),
#  ('David Guetta', 'D-Block Europe', 1),
#  ('David Guetta', 'Daddy Yankee', 1),
#  ('David Guetta', 'Farruko', 1),
#  ('David Guetta', 'Fetty Wap', 1),
#  ('David Guetta', 'Jung Kook', 1),
#  ('David Guetta', 'Latto', 1),
#  ('David Guetta', 'Lil Wayne', 1),
#  ('David Guetta', 'Ludacris', 1),
#  ('David Guetta', 'NATTI NATASHA', 1),
#  ('David Guetta', 'RAYE', 1),
#  ('David Guetta', 'Sean Paul', 1),
#  ('David Guetta', 'Snoop Dogg', 1),
#  ('David Guetta', 'USHER', 1),
#  ('David Guetta', 'Zara Larsson', 1),
#  ('David Kushner', 'Lost Frequencies', 1),
#  ('Davido', 'Chris Brown', 1),
#  ('Davido', 'David Guetta', 1),
#  ('Davido', 'Disclosure', 1),
#  ('Davido', 'Khalid', 1),
#  ('Davido', 'Nicki Minaj', 1),
#  ('Davido', 'Summer Walker', 1),
#  ('Davido', 'Tems', 1),
#  ('De La Ghetto', 'Arcángel', 1),
#  ('De La Ghetto', 'Bad Bunny', 1),
#  ('Dean Lewis', 'Martin Garrix', 1),
#  ('Dei V', 'Bad Bunny', 1),
#  ('Dei V', 'Eladio Carrion', 1),
#  ('Dei V', 'Hades66', 1),
#  ('Dei V', 'Jay Wheeler', 1),
#  ('Dei V', 'Omar Courtz', 1),
#  ('Dei V', 'Sech', 1),
#  ('Denzel Curry', 'Ty Dolla $ign', 1),
#  ('Diljit Dosanjh', 'Sia', 1),
#  ('Dimitri Vegas', 'Daddy Yankee', 1),
#  ('Dimitri Vegas', 'Martin Garrix', 1),
#  ('Dimitri Vegas', 'Steve Aoki', 1),
#  ('Diplo', 'French Montana', 1),
#  ('Diplo', 'Lil Nas X', 1),
#  ('Doechii', 'Tyler, The Creator', 1),
#  ('Doja Cat', 'Bebe Rexha', 1),
#  ('Doja Cat', 'JID', 1),
#  ('Doja Cat', 'Lil Nas X', 1),
#  ('Dolly Parton', 'Beyoncé', 1),
#  ('Don Omar', 'Chencho Corleone', 1),
#  ('Don Omar', 'Wisin', 1),
#  ('Don Toliver', 'Eminem', 1),
#  ('Don Toliver', 'Playboi Carti', 1),
#  ('Don Toliver', 'Roddy Ricch', 1),
#  ('Don Toliver', 'Skrillex', 1),
#  ('Don Toliver', '¥$', 1),
#  ('Dr. Dre', 'Eminem', 1),
#  ('Drake', 'Bad Bunny', 1),
#  ('Drake', 'Beyoncé', 1),
#  ('Drake', 'Camila Cabello', 1),
#  ('Drake', 'Eminem', 1),
#  ('Drake', 'French Montana', 1),
#  ('Drake', 'Kanye West', 1),
#  ('Drake', 'Lil Baby', 1),
#  ('Drake', 'Migos', 1),
#  ('Drake', 'SZA', 1),
#  ('Drake', 'Timbaland', 1),
#  ('Dua Lipa', 'Madonna', 1),
#  ('Dua Lipa', 'Major Lazer', 1),
#  ('Duki', 'Bad Bunny', 1),
#  ('Duki', 'Cazzu', 1),
#  ('Duki', 'KHEA', 1),
#  ('Ed Sheeran', 'Beyoncé', 1),
#  ('Ed Sheeran', 'Eminem', 1),
#  ('Ed Sheeran', 'Luke Combs', 1),
#  ('El Bogueto', 'El Malilla', 1),
#  ('Eladio Carrion', 'Bryant Myers', 1),
#  ('Eladio Carrion', 'Sech', 1),
#  ('Ellie Goulding', 'Diplo', 1),
#  ('Ellie Goulding', 'HUGEL', 1),
#  ('Ellie Goulding', 'J Balvin', 1),
#  ('Ellie Goulding', 'Juice WRLD', 1),
#  ('Ellie Goulding', 'Kygo', 1),
#  ('Ellie Goulding', 'Major Lazer', 1),
#  ('Ellie Goulding', 'Swae Lee', 1),
#  ('Ellie Goulding', 'Topic', 1),
#  ('Elton John', '6LACK', 1),
#  ('Elton John', 'Miley Cyrus', 1),
#  ('Eminem', 'Snoop Dogg', 1),
#  ('FISHER', 'Bob Marley & The Wailers', 1),
#  ('Fall Out Boy', 'Demi Lovato', 1),
#  ('Farruko', 'Alan Walker', 1),
#  ('Farruko', 'Arcángel', 1),
#  ('Farruko', 'Chencho Corleone', 1),
#  ('Farruko', 'DJ Luian', 1),
#  ('Farruko', 'Marshmello', 1),
#  ('Farruko', 'Sabrina Carpenter', 1),
#  ('Farruko', 'Sean Paul', 1),
#  ('Farruko', 'Sech', 1),
#  ('Farruko', 'Wisin', 1),
#  ('Feid', 'Bad Bunny', 1),
#  ('Feid', 'Daddy Yankee', 1),
#  ('Feid', 'Sech', 1),
#  ('Felix Jaehn', 'Calum Scott', 1),
#  ('Felix Jaehn', 'Elley Duhé', 1),
#  ('Felix Jaehn', 'Ray Dalton', 1),
#  ('Flo Rida', 'Alan Walker', 1),
#  ('Flo Rida', 'ENHYPEN', 1),
#  ('Flo Rida', 'Sia', 1),
#  ('Flo Rida', 'T-Pain', 1),
#  ('Florida Georgia Line', 'Alesso', 1),
#  ('Frank Ocean', 'Steve Lacy', 1),
#  ('Fred again..', 'Lil Yachty', 1),
#  ('French Montana', 'The Neighbourhood', 1),
#  ('Future', 'Ariana Grande', 1),
#  ('Future', 'Chance the Rapper', 1),
#  ('Future', 'DJ Snake', 1),
#  ('Future', 'Ed Sheeran', 1),
#  ('Future', 'Halsey', 1),
#  ('Future', 'J. Cole', 1),
#  ('Future', 'Jeremih', 1),
#  ('Future', 'Marshmello', 1),
#  ('Future', 'Meek Mill', 1),
#  ('Future', 'Pharrell Williams', 1),
#  ('Future', 'Post Malone', 1),
#  ('Future', 'Rihanna', 1),
#  ('Future', 'Swae Lee', 1),
#  ('Future', 'The Kid LAROI', 1),
#  ('G-Eazy', 'A$AP Rocky', 1),
#  ('G-Eazy', 'Bebe Rexha', 1),
#  ('G-Eazy', 'Cardi B', 1),
#  ('G-Eazy', 'Charlie Puth', 1),
#  ('G-Eazy', 'Jack Harlow', 1),
#  ('G-Eazy', 'Martin Garrix', 1),
#  ('Gabry Ponte', 'Dimitri Vegas & Like Mike', 1),
#  ('Gabry Ponte', 'R3HAB', 1),
#  ('Gabry Ponte', 'Steve Aoki', 1),
#  ('George Michael', 'Queen', 1),
#  ('Glass Animals', 'Denzel Curry', 1),
#  ('GloRilla', 'Cardi B', 1),
#  ('GloRilla', 'Don Toliver', 1),
#  ('GloRilla', 'Lil Durk', 1),
#  ('GloRilla', 'Lil Wayne', 1),
#  ('GloRilla', 'Sexyy Red', 1),
#  ('GloRilla', 'Tyler, The Creator', 1),
#  ('Gorillaz', '6LACK', 1),
#  ('Gorillaz', 'Bad Bunny', 1),
#  ('Gorillaz', 'Elton John', 1),
#  ('Gorillaz', 'ScHoolboy Q', 1),
#  ('Gorillaz', 'Tame Impala', 1),
#  ('Gracie Abrams', 'benny blanco', 1),
#  ('Gucci Mane', '2 Chainz', 1),
#  ('Gucci Mane', 'Gunna', 1),
#  ('Gucci Mane', 'Lil Durk', 1),
#  ('Gucci Mane', 'Migos', 1),
#  ('Gucci Mane', 'The Weeknd', 1),
#  ('Gucci Mane', 'Young Thug', 1),
#  ('Gunna', 'Asake', 1),
#  ('Gunna', 'Chris Brown', 1),
#  ('Gunna', 'Drake', 1),
#  ('Gunna', 'Lil Durk', 1),
#  ('Gunna', 'Lil Uzi Vert', 1),
#  ('Gwen Stefani', 'Eminem', 1),
#  ('H.E.R.', 'Asake', 1),
#  ('HUGEL', 'Diplo', 1),
#  ('Hades66', 'Bryant Myers', 1),
#  ('Halsey', 'Calvin Harris', 1),
#  ('Halsey', 'Justin Timberlake', 1),
#  ('Halsey', 'Marshmello', 1),
#  ('Halsey', 'Pharrell Williams', 1),
#  ('Halsey', 'mgk', 1),
#  ('Hans Zimmer', 'Bastille', 1),
#  ('Hans Zimmer', 'Lady Gaga', 1),
#  ('Hungria', 'Ana Castela', 1),
#  ('Ice Spice', 'Central Cee', 1),
#  ('Ice Spice', 'DaBaby', 1),
#  ('Imagine Dragons', 'Ado', 1),
#  ('Imagine Dragons', 'Khalid', 1),
#  ('Imagine Dragons', 'Ty Dolla $ign', 1),
#  ('J Balvin', 'Arcángel', 1),
#  ('J Balvin', 'Camila Cabello', 1),
#  ('J Balvin', 'DJ Snake', 1),
#  ('J Balvin', 'Ed Sheeran', 1),
#  ('J Balvin', 'El Bogueto', 1),
#  ('J Balvin', 'El Malilla', 1),
#  ('J Balvin', 'Farruko', 1),
#  ('J Balvin', 'Feid', 1),
#  ('J Balvin', 'HUGEL', 1),
#  ('J Balvin', 'Imagine Dragons', 1),
#  ('J Balvin', 'JHAYCO', 1),
#  ('J Balvin', 'Khalid', 1),
#  ('J Balvin', 'ROSALÍA', 1),
#  ('J Balvin', 'Sean Paul', 1),
#  ('J Balvin', 'Sech', 1),
#  ('J Balvin', 'Sky Rompiendo', 1),
#  ('J Balvin', 'Tyga', 1),
#  ('J Balvin', 'Wisin & Yandel', 1),
#  ('J Balvin', 'Young Miko', 1),
#  ('J Balvin', 'benny blanco', 1),
#  ('J. Cole', 'Ty Dolla $ign', 1),
#  ('JAY-Z', 'Beyoncé', 1),
#  ('JAY-Z', 'Bon Iver', 1),
#  ('JAY-Z', 'John Legend', 1),
#  ('JAY-Z', 'Lil Wayne', 1),
#  ('JENNIE', 'Dominic Fike', 1),
#  ('JID', 'Denzel Curry', 1),
#  ('Jack Harlow', 'Eminem', 1),
#  ('Jack Harlow', 'Jung Kook', 1),
#  ('James Arthur', 'Lost Frequencies', 1),
#  ('Jason Derulo', 'French Montana', 1),
#  ('Jason Derulo', 'R3HAB', 1),
#  ('Jason Derulo', 'Sia', 1),
#  ('Jay Wheeler', 'Bryant Myers', 1),
#  ('Jay Wheeler', 'Hades66', 1),
#  ('Jelly Roll', 'Eminem', 1),
#  ('Jelly Roll', 'Halsey', 1),
#  ('Jelly Roll', 'OneRepublic', 1),
#  ('Jelly Roll', 'Russ', 1),
#  ('Jelly Roll', 'mgk', 1),
#  ('Jeremih', 'Chris Brown', 1),
#  ('Jesse & Joy', 'Pablo Alborán', 1),
#  ('Jessie J', 'Ariana Grande', 1),
#  ('Jhené Aiko', 'Ty Dolla $ign', 1),
#  ('Joey Bada$$', 'Kendrick Lamar', 1),
#  ('John Legend', 'Stevie Wonder', 1),
#  ('John Mayer', 'Lizzy McAlpine', 1),
#  ('John Mayer', 'Zedd', 1),
#  ('Jonas Blue', 'Felix Jaehn', 1),
#  ('Jonas Blue', 'RAYE', 1),
#  ('Jonas Blue', 'Sabrina Carpenter', 1),
#  ('Jonas Blue', 'Tiësto', 1),
#  ('Jorja Smith', 'Burna Boy', 1),
#  ('Jorja Smith', 'Sonder', 1),
#  ('Juice WRLD', 'Fall Out Boy', 1),
#  ...]

# %%
# Load output from the cell above
result = _ # type: ignore

# Convert the result to a DataFrame
data_frame = result.DataFrame()

# Display the first few rows of the DataFrame
data_frame.head()
# Out:
#         artist_1                   artist_2  collaboration_count
# 0   Metro Boomin                     Future                   34
# 1  Dimitri Vegas  Dimitri Vegas & Like Mike                   14
# 2          Gunna                 Young Thug                   11
# 3   Travis Scott                 Young Thug                   11
# 4     Keinemusik                  Adam Port                   10

# %% [markdown]
# # Show tracks
# List the first couple of tracks of the artist pair with the highest collaboration count.

# %%
# Define the specific artist pair
artist_1, artist_2 = data_frame.iloc[0]["artist_1"], data_frame.iloc[0]["artist_2"]

# %%
# %%sql
# SELECT DISTINCT
#   Track.name AS track_name,
#   Track.id AS track_id
# FROM Track
# JOIN TrackArtist ON Track.id = TrackArtist.track_id
# JOIN Artist ON TrackArtist.artist_id = Artist.id
# WHERE Artist.name IN (:artist_1, :artist_2)
#   AND Track.popularity > :track_popularity
#   AND Artist.popularity > :artist_popularity
# Out:
#  * sqlite:///../db/spotify.sqlite
# Done.
# [('All I Know', '0NWqNXBJTpXbkI5rPWNy3p'),
#  ('Cold (feat. Future)', '2NlTOhsAamXOaZciOXbITb'),
#  ('Thrusting (feat. Swae Lee & Future)', '4ZrutH1rzpA4v3Bg9nma55'),
#  ('Turn On The Lights again.. (feat. Future & Fred again..) - Anyma Remix', '4ptnQ0kQnN1U1Ig8TSslj6'),
#  ('Fine Whine (feat. Joe Fox, Future & M.I.A.)', '2WxzLbJfPA2vJGxQiKd7Jq'),
#  ('On Time (with John Legend)', '0YFqKxV9uNu6LUeYkLOKRS'),
#  ('Superhero (Heroes & Villains) [with Future & Chris Brown]', '0vjeOZ3Ft5jvAi9SBFJm1j'),
#  ('Too Many Nights (feat. Don Toliver & with Future)', '2Hh3ETdQKrmSI3QS0hme7g'),
#  ('Raindrops (Insane) [with Travis Scott]', '1pacwLXyRO47ka0v6LTIiY'),
#  ('Umbrella (with 21 Savage & Young Nudy)', '2Yt4SXIgmoaPZHGdRafp4P'),
#  ('Trance (with Travis Scott & Young Thug)', '5wG3HvLhF6Y5KTGlK0IW3J'),
#  ('Around Me (feat. Don Toliver)', '221qmpQeBNV87sUjQeUTVH'),
#  ('Metro Spider (with Young Thug)', '2VtgzixdB967bHDNu5A1nh'),
#  ("I Can't Save You (Interlude) [with Future & feat. Don Toliver]", '2N9LEu6Pf8nDcp3GjWJT1Z'),
#  ("Creepin' (with The Weeknd & 21 Savage)", '2dHHgzDwk4BJdRwy9uXhTO'),
#  ('Niagara Falls (Foot or 2) [with Travis Scott & 21 Savage]', '4WuOWVnAqvEQxgSRrspBgt'),
#  ("Walk Em Down (Don't Kill Civilians) [with 21 Savage & feat. Mustafa]", '1UsQe17Ef7tV1ahFqHEFR3'),
#  ('Lock On Me (with Travis Scott & Future)', '0OoNzMdPSgbkM5MkcuEZfm'),
#  ('Feel The Fiyaaaah (with A$AP Rocky & feat. Takeoff)', '3SsJ17EnPIu1B4GZshqjIS'),
#  ('All The Money (with Gunna) [Bonus]', '4a1fh9vJMMoRjNrBmEWoM0'),
#  ("We Still Don't Trust You", '7sVbKoBdhXtYCEOO6qC1SN'),
#  ('Drink N Dance', '0SdpzQRdK8BdSV57rn6AZZ'),
#  ('Out Of My Hands', '2BOpFmZQ89Rjm2wvmud1MU'),
#  ('Jealous', '4k8XSN1nCJ0rMf4OKF3zEz'),
#  ('This Sunday', '5pF8pF6U8ZDGTQmTY71hYn'),
#  ('Luv Bad Bitches', '6Gf8Op8esgwchp44p1tIDp'),
#  ('Amazing (Interlude)', '5sOsYuB0SfyKzAeW3BXHjq'),
#  ('All to Myself', '0lOQaZwX9AkAiSvObh4G70'),
#  ('Nights Like This', '6c0rii1TOf2fvq3hhqqExW'),
#  ('Came to the Party', '0ho8zpOysOSWZM9C4jALaV'),
#  ('Right 4 You', '1Aw7MLqN5oqvIva5KWDpGl'),
#  ('Mile High Memories', '20BnS6yXNbYNVgPepicE1W'),
#  ('Overload', '2Cl3OfIwpKJFyJIimbGPCx'),
#  ('Gracious', '3qm3IN6Yx53r3NIououTey'),
#  ('Beat It', '7lsepdNR69a3PS9pWMNICd'),
#  ('Always Be My Fault', '1FIwzmULOKGNmo5bOJqW0P'),
#  ('One Big Family', '40vqMm30NcrokceG9auURz'),
#  ('Red Leather', '4Dx4e0X5dR6TW85dtFU42x'),
#  ('Nobody Knows My Struggle', '7nQXU7lu0RhVOSmsa3teKj'),
#  ('All My Life', '6J9ULUfgdVZfWnofbtLkfh'),
#  ('Crossed Out', '3CWXBLm0HSyJQIoTCFM12e'),
#  ('Crazy Clientele', '3GlQVf7QbQv1bro2mPL3K4'),
#  ('Show of Hands', '0cGn4vxyoBftN61XUv2aQk'),
#  ('Streets Made Me A King', '4Orf7Hvci6SZrPIoUjGuFY'),
#  ('Annihilate (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, Lil Wayne, Offset)', '39MK3d3fonIP8Mz9oHCTBB'),
#  ('Am I Dreaming (Metro Boomin & A$AP Rocky, Roisee)', '6Ec5LeRzkisa5KJtwLfOoW'),
#  ('All The Way Live (Spider-Man: Across the Spider-Verse) (Metro Boomin & Future, Lil Uzi Vert)', '0B6g379TMw0nYGXA7y5xHz'),
#  ('Hummingbird (Metro Boomin & James Blake)', '6HexNTb392JS071DoTGo0y'),
#  ('Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, NAV, feat. A Boogie Wit da Hoodie)', '5rurggqwwudn9clMdcchxT'),
#  ('Link Up (Metro Boomin & Don Toliver, Wizkid feat. BEAM & Toian) - Spider-Verse Remix (Spider-Man: Across the Spider-Verse )', '0y8Pu7x5jXgUjOIJvQIF5L'),
#  ('Self Love (Spider-Man: Across the Spider-Verse) (Metro Boomin & Coi Leray)', '0AAMnNeIc6CdnfNU85GwCH'),
#  ('Home (Metro Boomin & Don Toliver, Lil Uzi Vert)', '2qlBAT108lYOzlXhBxBqEv'),
#  ('Nonviolent Communication (Metro Boomin & James Blake, A$AP Rocky, 21 Savage)', '3xMnPIvsaWwzHzqqzaihEX'),
#  ('Nas Morales (Metro Boomin & Nas)', '4mTKCa00WAZS2ag4GYwu0t'),
#  ('Flex Up (feat. Future & Playboi Carti)', '5Ryu0SlsYjKh78RkJUONFr'),
#  ('Pardon Me (Lil Yachty feat. Future & Mike WiLL Made-It)', '1sxGIhaxY8eF52e1TlShSP'),
#  ('Am I Dreaming', '46631VBdAu3LkySeMIHJtd'),
#  ('Enjoy The Show (feat. Future)', '637oNhilCI9UlkWkUW4Grt'),
#  ('Die For Me (feat. Future & Halsey)', '2C6WXnmZ66tHhHlnvwePiK'),
#  ('Double Fantasy (with Future)', '4VMRsbfZzd3SfQtaJ1Wpwi'),
#  ("What's Hatnin'", '1p5M91qghUkzS4gwuMM22B'),
#  ('Private Landing (feat. Justin Bieber & Future)', '4EDTT4kSqfpc0FKuxfNo2E'),
#  ('Private Landing (feat. Justin Bieber & Future)', '2Ryzn1QqRKIKbAMNEXbLSB'),
#  ('3500 (feat. Future & 2 Chainz)', '1SGt65i9AnXYdDQt1AtDRH'),
#  ('Private Landing (feat. Justin Bieber & Future)', '52NGJPcLUzQq5w7uv4e5gf'),
#  ('Smoke Break (feat. Future)', '1Uq3IOIy1CUlHUgP6vWpum'),
#  ('Everyday', '30TmLgK0ja5O8q9l4BShIX'),
#  ('Unicorn Purp (feat. Young Thug & Gunna)', '2U3LJfQB0ALLxC7Yy0QW7l'),
#  ('First Off (feat. Travis Scott)', '3WRIaWsws011vHMd9uzPjG'),
#  ('LIL DEMON', '5UwhSyAaU6b5RHeYPzxZld'),
#  ('SOUTH OF FRANCE - REMIX', '2C11qhXSCvVzGogwOTP6aZ'),
#  ('TELEKINESIS (feat. SZA & Future)', '1i9lZvlaDdWDPyXEE95aiq'),
#  ('TEFLON DON', '2aGF1a9126wvzwrK01DLff'),
#  ('BEAUTIFUL (feat. Future & SZA)', '5kYSScXYOZYyi0fxramiW6'),
#  ('Lookin Exotic', '6Mz7ULRwNSCOdut6M3tNs2'),
#  ('Teen X (feat. Future)', '5uYqmEN6TAAE8ss8YmprNV'),
#  ('Rollin (feat. Future & Khalid)', '3FDrI0FLKzrYQiWxPhqV2W'),
#  ('FRANCHISE (feat. Future, Young Thug & M.I.A.) - REMIX', '6qUabsNxudatEFedWGHoDh'),
#  ('LIKE ME (feat. 42 Dugg & Lil Baby)', '3gOL6mYIq19Oq8raxIntrV'),
#  ('My Collection', '0526DaOuV7mRlPKxhMSJKw'),
#  ('Incredible', '2qwn6whaZf7gax7SaqUZSC'),
#  ('Xanny Family', '0BzDQgmeRdA4V71VhfBvXT'),
#  ('Rocket Ship', '4HfaOznGhHYWqPtpLYz2PB'),
#  ('End Game', '2x0WlnmfG39ZuDmstl9xfX'),
#  ('Mask Off - Marshmello Remix', '5rK0pyEObO4DBFLy682QvR'),
#  ('Life Is Good (feat. Drake)', '5yY9lUy8nbvjM1Uyo1Uqoc'),
#  ('PIE (feat. Chris Brown)', '5FsJ8AUxW1KBypdhFvbdkd'),
#  ('F&N', '5YP6yKgGGsXKukqxXypVAf'),
#  ('Honest', '5ik5nMy8vdS2rXe7SAGt2K'),
#  ('Patek', '3f9RZbFJrmttvXYwiwqDlb'),
#  ('Solo', '4lH6nENd1y81jp7Yt9lTBX'),
#  ('Mad Max', '2i2qDe3dnTl6maUE31FO7c'),
#  ('March Madness', '3WcC6NH9J77xPEvj1SOL7z'),
#  ('Do You Mind (feat. Nicki Minaj, Chris Brown, August Alsina, Jeremih, Future & Rick Ross)', '6ezg5Mm5UEEi3Oqsbb7Cjn'),
#  ('Rap Saved Me (feat. Quavo)', '0tdCy39PgWN8LFWu34ORn3'),
#  ('Jump Out the Face (feat. Future)', '17AS0y6FnHdYImAPUydAJg'),
#  ('Sup Mate (feat. Future)', '0zNHMc1cGKe4MO5rtGtKRh'),
#  ('pushin P (feat. Young Thug)', '3XOalgusokruzA5ZBA2Qcb'),
#  ('I Wanna Be With You', '2EAHXJbcFLmREbJCTv2RnD'),
#  ('Diamonds Dancing', '2AGottAzfC8bHzF7kEJ3Wa'),
#  ('née-nah', '6TdFkofgTvN0WfnWFmh4a6'),
#  ('Cinderella', '0hKtu53OlIFXVuYkZwcn3o'),
#  ('Hallucinating', '7IeHIGriFrJaTeaC4W0a8W'),
#  ('Trapped In The Sun', '6QeUzTuBoasiii8nevDciq'),
#  ('Perkys Calling', '05nB8pRwwbKA2fsKK1nOyE'),
#  ('Blackout', '0B0Xu2ih8fWpcwyxAt1c7m'),
#  ('Crushed Up', '7wcyO1rrH3Ru4t659IjG41'),
#  ("I'm so Groovy", '2Nfd2ITp4WkI1aoZlYpZwg'),
#  ("WHAT'S THE MOVE? (feat. Future and BabyDrill)", '0oqnZWNBvobs1t181f45Ck'),
#  ("Ain't No Love", '72qABvaqn3TP6drO2tByA6'),
#  ('Claustrophobic', '57ELn9TPDIhrpl0dasS465'),
#  ('Jersey', '2ACys0pX0SjmpQmQWzp7wt'),
#  ('Astronauts', '2vs5ubqg8QUbfyWZpMfvWe'),
#  ('7 Am Freestyle', '1hHe7cirScEJWgAS0JFqTL'),
#  ('Fuck Up Some Commas', '49zD0wr2S3d0lZPib0K4e1'),
#  ('Blasé (feat. Future & Rae Sremmurd)', '1UYLxZIL4IicS6TaPUZFTH'),
#  ('Petty Too (feat. Future)', '0VlpgNPHWCyh8xxLcaK2fp'),
#  ('Woah', '37rxbUlFTtQMX2JxirVGi1'),
#  ('Hardly', '7EtAE242kivzlxxOAL29bS'),
#  ('Draco', '4GkkxswcdEt1tkSyiRzgnC'),
#  ('Move That Dope (feat. Pharrell, Pusha T & Casino)', '7GEidxhfGNteiW9n0kLyxH'),
#  ('Dum, Dumb, and Dumber (with Young Thug & Future)', '5GZ0currErGJhl0G0yxgRg'),
#  ('Fine China', '5274I4mUMnYczyeXkGDWZN'),
#  ('Life Is Good (feat. Drake)', '1K5KBOgreBi5fkEHvg5ap3'),
#  ("I'm The Plug", '6bqtKURdSWkInAJHDkuaL0'),
#  ('Plastic Bag', '76kyKtPLsFbQkdQ86QrkF4'),
#  ('Young Metro', '3OxL6MuctgZp1e0zxoAZhH'),
#  ('Mask Off', '0VgkVdmE4gld66l8iyGjgx'),
#  ('Rent Money', '5W9QCBJ6Em0XWX333YrNhc'),
#  ('Turn On The Lights again.. (feat. Future)', '6gdDu39yYqPcaTgCwYEW8i'),
#  ('Ric Flair Drip (with Metro Boomin)', '7sO5G9EABYOXQKNPNiE9NR'),
#  ('Rollin (feat. Future & Khalid)', '0lMbuWUpfTWhEmOKxppEau'),
#  ('Darth Vader', '7vg47qMIEdLfNdTE3WLf0T'),
#  ('Jumpman', '27GmP9AWRs744SzKcpJsTZ'),
#  ('New Level (feat. Future)', '25rc1PFgPvtV6GFSloyOI0'),
#  ('Selfish (feat. Rihanna)', '6yHkPtl6UQ7RjtJLBPzbJw'),
#  ('Turn Yo Clic Up (feat. Future)', '2IHdMccpnU0PGHGltqM2Sq'),
#  ('My Savages', '6UgVTEP2WQl1okEuImI8Hg'),
#  ('Type Shit', '28drn6tQo95MRvO0jQEo5C'),
#  ('Realer N Realer', '4VMiNOpnjRwSCwmHaUfOMM'),
#  ('Fly Shit Only', '1ANYHWUz5NqPu2EBALGK9Z'),
#  ('Hold That Heat (feat. Travis Scott)', '6OrTKLtcF7EBayOV2QqkSK'),
#  ('U Are My High (with Future)', '0ITaSRuI0L1RNL7ZNYTTi7')]

# %%
# Load the output from the cell above
result = _ # type: ignore

# Execute the query and load the data into a DataFrame
top_tracks_df = result.DataFrame()

# Display the top tracks
top_tracks_df.head()
# Out:
#                                           track_name                track_id
# 0                                         All I Know  0NWqNXBJTpXbkI5rPWNy3p
# 1                                Cold (feat. Future)  2NlTOhsAamXOaZciOXbITb
# 2                Thrusting (feat. Swae Lee & Future)  4ZrutH1rzpA4v3Bg9nma55
# 3  Turn On The Lights again.. (feat. Future & Fre...  4ptnQ0kQnN1U1Ig8TSslj6
# 4        Fine Whine (feat. Joe Fox, Future & M.I.A.)  2WxzLbJfPA2vJGxQiKd7Jq

# %% [markdown]
# # Create Collaboration Graph
# Create a NetworkX graph from the DataFrame, filtering edges based on a minimum number of collaborations.

# %%
# Define filter for minimum amount of collaborations
min_col = 3

# %%
# Create NetworkX graph from the DataFrame, filtering edges based on a minimum number of collaborations
def create_graph(data_frame: pd.DataFrame, min_collaborations: int = 3) -> nx.Graph:
    G = nx.Graph()
    
    # Use itertuples() for better performance
    for row in data_frame.itertuples(index=False):
        G.add_edge(row.artist_1, row.artist_2, weight=row.collaboration_count)

    # Filter low-weight edges
    filtered_edges = [(u, v) for u, v, d in G.edges(data=True) if d["weight"] > min_collaborations]
    return G.edge_subgraph(filtered_edges).copy()

# Create graph with a minimum collaboration threshold
G_filtered = create_graph(data_frame, min_col)
print(f"Nodes: {G_filtered.number_of_nodes()}, Edges: {G_filtered.number_of_edges()}")
# Out:
# Nodes: 268, Edges: 474

# %% [markdown]
# # Calculate Centrality Measures
# Calculate degree centrality and betweenness centrality for the nodes in the graph.

# %%
# Centrality measures
degree_centrality = nx.degree_centrality(G_filtered)
betweenness_centrality = nx.betweenness_centrality(G_filtered)

# %%
# Sets centrality values to 1 for max to 0 for min
def normalize_centrality(centrality_dict):
    values = list(centrality_dict.values())
    scaler = MinMaxScaler()
    normalized_values = scaler.fit_transform([[v] for v in values]).flatten()
    
    return dict(zip(centrality_dict.keys(), normalized_values))

# Degree and betweenness centrality
norm_degree_cen = normalize_centrality(degree_centrality)
norm_betweenness_cen = normalize_centrality(betweenness_centrality)

# Display top 5 artists
print("\n🎵 Top 5 Artists by Degree Centrality:")
for artist, score in sorted(norm_degree_cen.items(), key=lambda x: x[1], reverse=True)[:5]:
    print(f"{artist}: {score:.3f}")

print("\n🔗 Top 5 Artists by Betweenness Centrality:")
for artist, score in sorted(norm_betweenness_cen.items(), key=lambda x: x[1], reverse=True)[:5]:
    print(f"{artist}: {score:.3f}")
# Out:
# 🎵 Top 5 Artists by Degree Centrality:
# Justin Bieber: 1.000
# Future: 0.923
# Travis Scott: 0.846
# The Weeknd: 0.731
# David Guetta: 0.615
#
# 🔗 Top 5 Artists by Betweenness Centrality:
# Justin Bieber: 1.000
# David Guetta: 0.733
# Bad Bunny: 0.652
# The Weeknd: 0.598
# J Balvin: 0.593

# %% [markdown]
# # Detect Communities
# Use the Louvain method to detect communities within the graph and print the number of detected communities.

# %%
# Use the Louvain method to detect communities within the graph
partition = community_louvain.best_partition(G_filtered)

# Print the number of detected communities
num_communities = len(set(partition.values()))
print(f"Detected {num_communities} artist communities.")
# Out:
# Detected 23 artist communities.

# %% [markdown]
# # Visualize Collaboration Network
# Each dot represents an artist. Each line represents a relation, thicker lines represent more collaborations between the artists.

# %%
# Create a Pyvis network visualization
def visualize_graph_pyvis(G: nx.Graph):
    net = Network(notebook=True, width="100%", height="700px", bgcolor="#222222", font_color="white")
    
    for node in G.nodes():
        net.add_node(node, title=node, color="blue")
    
    for edge in G.edges(data=True):
        net.add_edge(edge[0], edge[1], value=edge[2].get('weight', 1))

    net.toggle_physics(True)  # Enable physics for better layout
    
    net.set_options("""
        var options = {
          "nodes": { "shape": "dot", "size": 10 },
          "edges": { "color": "gray", "width": 1 },
          "physics": {
            "barnesHut": { "gravitationalConstant": -30000, "centralGravity": 0.3 }
          }
        }
    """)
    
    net.show("artist_network.html")

visualize_graph_pyvis(G_filtered)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# artist_network.html
