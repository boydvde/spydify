# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries

# %%
# %pip install pandas networkx community scikit-learn pyvis ipython-sql

# %%
import networkx as nx
import pandas as pd
import community.community_louvain as community_louvain
from sklearn.preprocessing import MinMaxScaler
from pyvis.network import Network

# %% [markdown]
# # Load Data from Database
# Load data from the SQLite database into a pandas DataFrame using a SQL query. The query selects pairs of artists who have collaborated on tracks, along with the count of their collaborations. The data is filtered based on the popularity of the artists and tracks.

# %%
# Define the filters to apply to the data
artist_popularity = 60 # The minimum popularity of an artist
track_popularity = 30 # The minimum popularity of a track

# %%
# Load the ipython-sql extension
# %load_ext sql

# Connect to the SQLite database
# %sql sqlite:///../db/spotify.sqlite
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SELECT a1.name AS artist_1,
#     a2.name AS artist_2,
#     COUNT(*) AS collaboration_count
# FROM TrackArtist ta1
# JOIN TrackArtist ta2 ON ta1.track_id = ta2.track_id
# AND ta1.artist_id < ta2.artist_id
# JOIN Artist a1 ON ta1.artist_id = a1.id
# JOIN Artist a2 ON ta2.artist_id = a2.id
# JOIN Track ON ta1.track_id = Track.id
# WHERE a1.name IS NOT NULL
# AND a2.name IS NOT NULL
# AND Track.popularity > :track_popularity
# AND a1.popularity > :artist_popularity
# AND a2.popularity > :artist_popularity
# GROUP BY a1.name, a2.name
# ORDER BY collaboration_count DESC
# Out:
#  * sqlite:///../db/spotify.sqlite
# Done.
# [('Metro Boomin', 'Future', 39),
#  ('Rampa', '&ME', 38),
#  ('Adam Port', '&ME', 37),
#  ('Rampa', 'Adam Port', 37),
#  ('Keinemusik', 'Adam Port', 33),
#  ('Dimitri Vegas', 'Dimitri Vegas & Like Mike', 32),
#  ('Rampa', 'Keinemusik', 32),
#  ('Keinemusik', '&ME', 30),
#  ('Ellie Goulding', 'Calvin Harris', 26),
#  ('Macklemore', 'Ryan Lewis', 25),
#  ('Macklemore', 'Macklemore & Ryan Lewis', 24),
#  ('Swae Lee', 'Rae Sremmurd', 20),
#  ('A$AP Rocky', 'A$AP Ferg', 18),
#  ('Ryan Lewis', 'Macklemore & Ryan Lewis', 18),
#  ('Future', 'Lil Uzi Vert', 16),
#  ('Metro Boomin', '21 Savage', 16),
#  ('Dimitri Vegas', 'Like Mike', 15),
#  ('Gunna', 'Young Thug', 15),
#  ('Jeremy Zucker', 'Chelsea Cutler', 15),
#  ('Labrinth', 'Sia', 15),
#  ('Metro Boomin', 'Don Toliver', 15),
#  ('A$AP Rocky', 'Playboi Carti', 14),
#  ('K-391', 'Alan Walker', 14),
#  ('Travis Scott', 'Young Thug', 14),
#  ('Sia', 'Diplo', 13),
#  ('D-Block Europe', 'cassö', 12),
#  ('Diplo', 'LSD', 12),
#  ('Diplo', 'Skrillex', 12),
#  ('Drake', 'Lil Wayne', 12),
#  ('Labrinth', 'Diplo', 12),
#  ('Labrinth', 'LSD', 12),
#  ('Naughty Boy', 'Sam Smith', 12),
#  ('Niklas Dee', 'Luca-Dante Spadafora', 12),
#  ('Quavo', 'Travis Scott', 12),
#  ('RAYE', 'D-Block Europe', 12),
#  ('RAYE', 'cassö', 12),
#  ('Sam Smith', 'Calvin Harris', 12),
#  ('Sia', 'LSD', 12),
#  ('Travis Scott', 'Metro Boomin', 12),
#  ('W&W', 'AXMO', 12),
#  ('A$AP Rocky', 'Juicy J', 11),
#  ('Future', 'Don Toliver', 11),
#  ('Vini Vici', 'Dimitri Vegas & Like Mike', 11),
#  ('Chance the Rapper', 'Justin Bieber', 10),
#  ('David Guetta', 'Bebe Rexha', 10),
#  ('Future', 'The Weeknd', 10),
#  ('Justin Timberlake', 'Anna Kendrick', 10),
#  ('Justin Timberlake', 'Daveed Diggs', 10),
#  ('Lady Gaga', 'Bradley Cooper', 10),
#  ('League of Legends', 'Arcane', 10),
#  ('Nicki Minaj', 'Ariana Grande', 10),
#  ('Pharrell Williams', 'Daft Punk', 10),
#  ('Sonny Fodera', 'Jazzy', 10),
#  ('Timmy Trumpet', 'Dimitri Vegas & Like Mike', 10),
#  ('Camila Cabello', 'Shawn Mendes', 9),
#  ('David Guetta', 'Sia', 9),
#  ('Fred again..', 'Headie One', 9),
#  ('Kid Cudi', 'Daveed Diggs', 9),
#  ('LUM!X', 'Gabry Ponte', 9),
#  ('Like Mike', 'Dimitri Vegas & Like Mike', 9),
#  ('Metro Boomin', 'A$AP Rocky', 9),
#  ('Metro Boomin', 'The Weeknd', 9),
#  ('Rick Ross', 'Lil Wayne', 9),
#  ('The Weeknd', 'Ariana Grande', 9),
#  ('Young Stoner Life', 'Young Thug', 9),
#  ('21 Savage', 'The Weeknd', 8),
#  ('A$AP Rocky', 'Tyler, The Creator', 8),
#  ('Akon', 'David Guetta', 8),
#  ('Camila Cabello', 'Ed Sheeran', 8),
#  ('Camilo', 'Evaluna Montaner', 8),
#  ('D.O.D', 'Jazzy', 8),
#  ('D.O.D', 'Sonny Fodera', 8),
#  ('DJ Khaled', 'Future', 8),
#  ('Daron Malakian', 'System Of A Down', 8),
#  ('Daveed Diggs', 'Anna Kendrick', 8),
#  ('David Guetta', 'Dimitri Vegas', 8),
#  ('David Guetta', 'Dimitri Vegas & Like Mike', 8),
#  ('Ely Oaks', 'LAVINIA', 8),
#  ('FAST BOY', 'Elley Duhé', 8),
#  ('Gunna', 'NAV', 8),
#  ('James Carter', 'Elley Duhé', 8),
#  ('James Carter', 'FAST BOY', 8),
#  ('Juice WRLD', 'Trippie Redd', 8),
#  ('Justin Bieber', 'DJ Snake', 8),
#  ('Justin Bieber', 'Don Toliver', 8),
#  ('Kid Cudi', 'Justin Timberlake', 8),
#  ('Kygo', 'Zak Abel', 8),
#  ('Lana Del Rey', 'The Weeknd', 8),
#  ('Lil Wayne', 'Chris Brown', 8),
#  ('MEDUZA', 'Elley Duhé', 8),
#  ('MEDUZA', 'FAST BOY', 8),
#  ('MEDUZA', 'Goodboys', 8),
#  ('MEDUZA', 'James Carter', 8),
#  ('MØ', 'Major Lazer', 8),
#  ('Olivia Rodrigo', 'Disney', 8),
#  ("Rag'n'Bone Man", 'Calvin Harris', 8),
#  ('The Weeknd', 'Lily-Rose Depp', 8),
#  ('The Weeknd', 'Playboi Carti', 8),
#  ('The Weeknd', 'Swedish House Mafia', 8),
#  ('Topic', 'A7S', 8),
#  ('Travis Scott', 'Future', 8),
#  ('W&W', 'Dimitri Vegas & Like Mike', 8),
#  ('Whethan', 'Elley Duhé', 8),
#  ('A$AP Rocky', 'French Montana', 7),
#  ('A$AP Rocky', 'ScHoolboy Q', 7),
#  ('Anthony Keyrouz', 'Besomorph', 7),
#  ('Big Sean', 'Kanye West', 7),
#  ('Calum Scott', 'Lost Frequencies', 7),
#  ('DJ Khaled', 'Lil Wayne', 7),
#  ('DJ Khaled', 'Rick Ross', 7),
#  ('DJ Khaled', 'Travis Scott', 7),
#  ('David Guetta', 'Ava Max', 7),
#  ('David Guetta', 'OneRepublic', 7),
#  ('Dua Lipa', 'Calvin Harris', 7),
#  ('Gryffin', 'Elley Duhé', 7),
#  ('Icona Pop', 'Charli xcx', 7),
#  ('JAY-Z', 'Beyoncé', 7),
#  ('Julien Baker', 'Phoebe Bridgers', 7),
#  ('Julien Baker', 'boygenius', 7),
#  ('Jung Kook', 'Charlie Puth', 7),
#  ('Justice', 'Tame Impala', 7),
#  ('Justin Bieber', 'USHER', 7),
#  ('Kah-Lo', 'Riton', 7),
#  ('Kane Brown', 'Marshmello', 7),
#  ('Kid Cudi', 'Troye Sivan', 7),
#  ('Kygo', 'Sandro Cavazza', 7),
#  ('Lucy Dacus', 'Julien Baker', 7),
#  ('Lucy Dacus', 'Phoebe Bridgers', 7),
#  ('Lucy Dacus', 'boygenius', 7),
#  ('Metro Boomin', 'James Blake', 7),
#  ('Metro Boomin', 'Swae Lee', 7),
#  ('Neoni', 'Besomorph', 7),
#  ('Nicki Minaj', 'Chris Brown', 7),
#  ('Nicki Minaj', 'David Guetta', 7),
#  ('Nicki Minaj', 'Lil Wayne', 7),
#  ('Quavo', 'Justin Bieber', 7),
#  ('Troye Sivan', 'Daveed Diggs', 7),
#  ('Wiz Khalifa', 'Juicy J', 7),
#  ('YG', 'Tyga', 7),
#  ('boygenius', 'Phoebe Bridgers', 7),
#  ('2 Chainz', 'Lil Wayne', 6),
#  ('A$AP Rocky', 'Skepta', 6),
#  ('Armin van Buuren', 'Vini Vici', 6),
#  ('BUNT.', 'CRO', 6),
#  ('BUNT.', 'Nate Traveller', 6),
#  ('Camila Cabello', 'Anna Kendrick', 6),
#  ('Charli xcx', 'Tiësto', 6),
#  ('Charli xcx', 'Troye Sivan', 6),
#  ('DJ Khaled', 'JAY-Z', 6),
#  ('DJ Khaled', 'Lil Baby', 6),
#  ('DaBaby', 'YoungBoy Never Broke Again', 6),
#  ('Daveed Diggs', 'Camila Cabello', 6),
#  ('David Guetta', 'AFROJACK', 6),
#  ('Ellie Goulding', 'Diplo', 6),
#  ('Elton John', 'Dua Lipa', 6),
#  ('Future', 'Justin Bieber', 6),
#  ('J Balvin', 'Bad Bunny', 6),
#  ('Jex', 'Martin Garrix', 6),
#  ('Justin Bieber', 'Ed Sheeran', 6),
#  ('Justin Bieber', 'Ludacris', 6),
#  ('Justin Bieber', 'benny blanco', 6),
#  ('Justin Timberlake', 'Camila Cabello', 6),
#  ('Justin Timberlake', 'Troye Sivan', 6),
#  ('Kid Cudi', 'Anna Kendrick', 6),
#  ('Kid Cudi', 'Camila Cabello', 6),
#  ('Lady Gaga', 'Tony Bennett', 6),
#  ('Lana Del Rey', 'Quavo', 6),
#  ('Lily-Rose Depp', 'JENNIE', 6),
#  ('MORTEN', 'David Guetta', 6),
#  ('Macklemore & Ryan Lewis', 'Ryan Lewis', 6),
#  ('Maddix', 'Hardwell', 6),
#  ('Metro Boomin', 'Lil Uzi Vert', 6),
#  ('Metro Boomin', 'Young Thug', 6),
#  ('Mustard', 'Ty Dolla $ign', 6),
#  ('Nile Rodgers', 'Daft Punk', 6),
#  ('Pharrell Williams', 'Nile Rodgers', 6),
#  ('Playboi Carti', 'Madonna', 6),
#  ('Rick Ross', 'JAY-Z', 6),
#  ('Rihanna', 'Calvin Harris', 6),
#  ('Sam Tinnesz', 'Tommee Profitt', 6),
#  ('Stormzy', 'Headie One', 6),
#  ('Tainy', 'Alvaro Diaz', 6),
#  ('The Weeknd', 'Daft Punk', 6),
#  ('The Weeknd', 'JENNIE', 6),
#  ('The Weeknd', 'Madonna', 6),
#  ('Travis Scott', 'The Weeknd', 6),
#  ('Young Stoner Life', 'Gunna', 6),
#  ('A Boogie Wit da Hoodie', 'NAV', 5),
#  ('A$AP Ferg', 'Playboi Carti', 5),
#  ('AJ Tracey', 'Headie One', 5),
#  ('Alok', 'Alan Walker', 5),
#  ('Alphaville', 'Ava Max', 5),
#  ('Alphaville', 'David Guetta', 5),
#  ('Armin van Buuren', 'Rivo', 5),
#  ('Au/Ra', 'Alan Walker', 5),
#  ('Ava Max', 'Alan Walker', 5),
#  ('Besomorph', 'Nito-Onna', 5),
#  ('Big Sean', 'Chris Brown', 5),
#  ('Big Sean', 'Metro Boomin', 5),
#  ('Big Sean', 'Rick Ross', 5),
#  ('Bring Me The Horizon', 'SLANDER', 5),
#  ('Bring Me The Horizon', 'blackbear', 5),
#  ('Broiler', 'Imagine Dragons', 5),
#  ('Cardi B', 'Camila Cabello', 5),
#  ('Cardi B', 'Ed Sheeran', 5),
#  ('DJ Khaled', 'Big Sean', 5),
#  ('DJ Khaled', 'Drake', 5),
#  ('David Guetta', 'Hypaton', 5),
#  ('David Guetta', 'Martin Garrix', 5),
#  ('Disciples', 'Calvin Harris', 5),
#  ('Don Toliver', 'Lil Uzi Vert', 5),
#  ('Drake', 'Chris Brown', 5),
#  ('Funk Wav', 'Calvin Harris', 5),
#  ('Future', 'Chris Brown', 5),
#  ('Future', 'Young Thug', 5),
#  ('Halsey', 'BTS', 5),
#  ('Hans Zimmer', 'Lady Gaga', 5),
#  ('ILLENIUM', 'Jon Bellion', 5),
#  ('Imagine Dragons', 'Arcane', 5),
#  ('JAY-Z', 'Rihanna', 5),
#  ('Jaden', 'Justin Bieber', 5),
#  ('Juanes', 'Morat', 5),
#  ('Julian Casablancas', 'Daft Punk', 5),
#  ('Justin Bieber', 'Chris Brown', 5),
#  ('Justin Bieber', 'Skrillex', 5),
#  ('Justin Bieber', 'The Kid LAROI', 5),
#  ('Justin Quiles', 'Danny Ocean', 5),
#  ('Kelly Clarkson', 'Ariana Grande', 5),
#  ('Kygo', 'Dean Lewis', 5),
#  ('Kygo', 'Gryffin', 5),
#  ('Kygo', 'HAYLA', 5),
#  ('Kygo', 'Miguel', 5),
#  ('Kygo', 'Nile Rodgers', 5),
#  ('Kygo', 'OneRepublic', 5),
#  ('Kygo', 'Sasha Alex Sloan', 5),
#  ('Megan Thee Stallion', 'GloRilla', 5),
#  ('Nicki Minaj', 'Drake', 5),
#  ('Nicki Minaj', 'Meek Mill', 5),
#  ('Nile Rodgers', 'Zak Abel', 5),
#  ('Offset', 'Quality Control', 5),
#  ('Ozuna', 'J Balvin', 5),
#  ('Pharrell Williams', 'Calvin Harris', 5),
#  ('Quavo', 'Offset', 5),
#  ('Rick Ross', 'Kanye West', 5),
#  ('SG Lewis', 'Tove Lo', 5),
#  ('SLANDER', 'blackbear', 5),
#  ('Sam Smith', 'Disclosure', 5),
#  ('Sam Smith', 'Kim Petras', 5),
#  ('Sebastian Yatra', 'Manuel Turizo', 5),
#  ('Selena Gomez', 'Coldplay', 5),
#  ('Sigala', 'Ely Oaks', 5),
#  ('Steve Aoki', 'Alan Walker', 5),
#  ('Swae Lee', 'Diplo', 5),
#  ('Tainy', 'Bad Bunny', 5),
#  ('Tainy', 'Rauw Alejandro', 5),
#  ('Taylor Swift', 'Post Malone', 5),
#  ('The Blessed Madonna', 'Dua Lipa', 5),
#  ('The Weeknd', 'Drake', 5),
#  ('Tiakola', 'Gazo', 5),
#  ('Timmy Trumpet', 'R3HAB', 5),
#  ('Tiësto', 'Ava Max', 5),
#  ('Topic', 'Daecolm', 5),
#  ('Topic', 'HUGEL', 5),
#  ('Travis Scott', '21 Savage', 5),
#  ('Travis Scott', 'Bad Bunny', 5),
#  ('Travis Scott', 'Gunna', 5),
#  ('Travis Scott', 'NAV', 5),
#  ('Tyga', 'Chris Brown', 5),
#  ('Wiz Khalifa', 'Ty Dolla $ign', 5),
#  ('Wizkid', 'Don Toliver', 5),
#  ('YG', 'Mustard', 5),
#  ('deadmau5', 'Kaskade', 5),
#  ('iann dior', 'mgk', 5),
#  ('will.i.am', 'Britney Spears', 5),
#  ('2 Chainz', 'Juicy J', 4),
#  ('21 Savage', 'Diddy', 4),
#  ('21 Savage', 'James Blake', 4),
#  ('50 Cent', 'Eminem', 4),
#  ('A Touch Of Class', 'R3HAB', 4),
#  ('A$AP Rocky', '21 Savage', 4),
#  ('A$AP Rocky', 'Dean Blunt', 4),
#  ('A$AP Rocky', 'Future', 4),
#  ('A$AP Rocky', 'Lil Yachty', 4),
#  ('Angèle', 'Dua Lipa', 4),
#  ('Anthony Keyrouz', 'Nito-Onna', 4),
#  ('Arcane', 'JID', 4),
#  ('Armin van Buuren', 'Oliver Heldens', 4),
#  ('Avicii', 'Sandro Cavazza', 4),
#  ('BUNT.', 'Elley Duhé', 4),
#  ('Bastille', 'Lost Frequencies', 4),
#  ('Big Sean', 'Ariana Grande', 4),
#  ('Big Sean', 'Justin Bieber', 4),
#  ('Big Sean', 'Lil Wayne', 4),
#  ('Bonn', 'Lost Frequencies', 4),
#  ('CamelPhat', 'Elderbrook', 4),
#  ('Charli xcx', 'Kim Petras', 4),
#  ('Coldplay', 'The Chainsmokers', 4),
#  ('DJ Khaled', '21 Savage', 4),
#  ('DJ Khaled', 'Bryson Tiller', 4),
#  ('DJ Khaled', 'Jeremih', 4),
#  ('DJ Khaled', 'Justin Bieber', 4),
#  ('DJ Khaled', 'Meek Mill', 4),
#  ('DJ Snake', 'Major Lazer', 4),
#  ('DaBaby', 'Dua Lipa', 4),
#  ('DaBaby', 'Lil Baby', 4),
#  ('Daecolm', 'Arash', 4),
#  ('Daecolm', 'HUGEL', 4),
#  ('David Guetta', 'Alesso', 4),
#  ('David Guetta', 'J Balvin', 4),
#  ('David Guetta', 'Justin Bieber', 4),
#  ('David Guetta', 'RAYE', 4),
#  ('Diplo', 'Major Lazer', 4),
#  ('Doja Cat', 'Ariana Grande', 4),
#  ('Don Toliver', 'Internet Money', 4),
#  ('Drake', 'Young Thug', 4),
#  ('Ellie Goulding', 'Juice WRLD', 4),
#  ('Ellie Goulding', 'Kygo', 4),
#  ('Ellie Goulding', 'Swae Lee', 4),
#  ('Felix Jaehn', 'Ray Dalton', 4),
#  ('Future', 'Lil Baby', 4),
#  ('Future', 'Swae Lee', 4),
#  ('Goodboys', 'Becky Hill', 4),
#  ('Gryffin', 'Calum Scott', 4),
#  ('HUGEL', 'Arash', 4),
#  ('Halsey', 'Calvin Harris', 4),
#  ('Halsey', 'Marshmello', 4),
#  ('Halsey', 'Stefflon Don', 4),
#  ('Halsey', 'The Chainsmokers', 4),
#  ('ILLENIUM', 'The Chainsmokers', 4),
#  ('Iggy Azalea', 'Ariana Grande', 4),
#  ('Imagine Dragons', 'JID', 4),
#  ('Ina Wroldsen', 'Alan Walker', 4),
#  ('Ink', 'The Chainsmokers', 4),
#  ('Ink', 'Zerb', 4),
#  ('Jaden', 'A$AP Rocky', 4),
#  ('Jess Glynne', 'Clean Bandit', 4),
#  ('Jess Glynne', 'Rudimental', 4),
#  ('Juicy J', 'Chris Brown', 4),
#  ('Juicy J', 'French Montana', 4),
#  ('Julia Michaels', 'JP Saxe', 4),
#  ('Justin Bieber', 'Major Lazer', 4),
#  ('Justin Bieber', 'Omah Lay', 4),
#  ('Justin Bieber', 'Post Malone', 4),
#  ('Justin Timberlake', 'Timbaland', 4),
#  ('KSHMR', 'Dimitri Vegas & Like Mike', 4),
#  ('KSHMR', 'Marnik', 4),
#  ('Kane Brown', 'Khalid', 4),
#  ('Kanye West', 'John Legend', 4),
#  ('Kehlani', 'Justin Bieber', 4),
#  ('Khalid', 'Disclosure', 4),
#  ('Kristin Chenoweth', 'Ariana Grande', 4),
#  ('Kygo', 'Calum Scott', 4),
#  ('Kygo', 'Tiësto', 4),
#  ('Kylie Minogue', 'Sia', 4),
#  ('Kylie Minogue', 'The Blessed Madonna', 4),
#  ('Lana Del Rey', 'A$AP Rocky', 4),
#  ('Lil Durk', 'NAV', 4),
#  ('Lil Durk', 'Young Thug', 4),
#  ('Lil Tecca', 'Internet Money', 4),
#  ('Lil Uzi Vert', 'Playboi Carti', 4),
#  ('Lost Frequencies', 'Kungs', 4),
#  ('MARINA', 'Clean Bandit', 4),
#  ('MEDUZA', 'Becky Hill', 4),
#  ('MEDUZA', 'Dermot Kennedy', 4),
#  ('MEDUZA', 'HAYLA', 4),
#  ('Mac Miller', 'Ariana Grande', 4),
#  ('Macklemore', 'Jess Glynne', 4),
#  ('Macklemore', 'Rudimental', 4),
#  ('Mark Ronson', 'Miley Cyrus', 4),
#  ('Marshmello', 'Bastille', 4),
#  ('Marshmello', 'Khalid', 4),
#  ('Martin Garrix', 'Bebe Rexha', 4),
#  ('Martin Garrix', 'Bonn', 4),
#  ('Metro Boomin', 'Offset', 4),
#  ('Mike WiLL Made-It', 'Future', 4),
#  ('Mustard', 'Roddy Ricch', 4),
#  ('Mustard', 'Wiz Khalifa', 4),
#  ('MØ', 'DJ Snake', 4),
#  ('MØ', 'Justin Bieber', 4),
#  ('NATTI NATASHA', 'Daddy Yankee', 4),
#  ('NATTI NATASHA', 'Dimitri Vegas', 4),
#  ('NATTI NATASHA', 'Dimitri Vegas & Like Mike', 4),
#  ('Naeleck', 'Marnik', 4),
#  ('Naeleck', 'VINAI', 4),
#  ('Nicki Minaj', 'Future', 4),
#  ('Nicki Minaj', 'Jeremih', 4),
#  ('Noah Kahan', 'Kelsea Ballerini', 4),
#  ('Pharrell Williams', 'Ariana Grande', 4),
#  ('Pharrell Williams', 'Justin Timberlake', 4),
#  ('Phoebe Bridgers', 'The National', 4),
#  ('Post Malone', 'DaBaby', 4),
#  ('Project Pat', 'A$AP Rocky', 4),
#  ('Quality Control', 'Lil Yachty', 4),
#  ('Quavo', 'Post Malone', 4),
#  ('Quavo', 'Quality Control', 4),
#  ('Quinn XCII', 'Chelsea Cutler', 4),
#  ('R3HAB', 'Calvin Harris', 4),
#  ('Regard', 'Dimitri Vegas & Like Mike', 4),
#  ('Rick Ross', 'Drake', 4),
#  ('Rick Ross', 'John Legend', 4),
#  ('Rick Ross', 'Wale', 4),
#  ('Sean Paul', 'Sia', 4),
#  ('Sebastian Yatra', 'Cali Y El Dandee', 4),
#  ('Sebastian Yatra', 'Dalmata', 4),
#  ('Sebastian Yatra', 'TINI', 4),
#  ('Selena Gomez', 'Charlie Puth', 4),
#  ('Selena Gomez', 'Kygo', 4),
#  ('Sigala', 'James Arthur', 4),
#  ('Skepta', 'Headie One', 4),
#  ('Stormzy', 'AJ Tracey', 4),
#  ('Stormzy', 'Ed Sheeran', 4),
#  ('Swedish House Mafia', 'John Martin', 4),
#  ('Tainy', 'J Balvin', 4),
#  ('Tainy', 'Yandel', 4),
#  ('Taylor Swift', 'Ed Sheeran', 4),
#  ('The Chainsmokers', 'Zerb', 4),
#  ('The Game', 'Lil Wayne', 4),
#  ('The Weeknd', 'Diddy', 4),
#  ('The Weeknd', 'Juicy J', 4),
#  ('The Weeknd', 'Young Thug', 4),
#  ('Timmy Trumpet', 'Dimitri Vegas', 4),
#  ('Tiësto', 'Martin Garrix', 4),
#  ('Tom Odell', 'Lost Frequencies', 4),
#  ('Topic', 'Arash', 4),
#  ('Travis Barker', 'iann dior', 4),
#  ('Travis Barker', 'mgk', 4),
#  ('Travis Scott', 'Miguel', 4),
#  ('Travis Scott', 'Offset', 4),
#  ('Troye Sivan', 'Anna Kendrick', 4),
#  ('Troye Sivan', 'Camila Cabello', 4),
#  ('Tyler, The Creator', 'Lil Wayne', 4),
#  ('VINAI', 'Marnik', 4),
#  ('Vintage Culture', 'Goodboys', 4),
#  ('YG', 'Quavo', 4),
#  ('Young Thug', 'Lil Yachty', 4),
#  ('Young Thug', 'NAV', 4),
#  ('blackbear', 'mgk', 4),
#  ('2 Chainz', '21 Savage', 3),
#  ('2 Chainz', 'Don Toliver', 3),
#  ('21 Savage', 'Don Toliver', 3),
#  ('21 Savage', 'Offset', 3),
#  ('6LACK', 'Khalid', 3),
#  ('A$AP Ferg', 'Denzel Curry', 3),
#  ('A$AP Rocky', 'Clams Casino', 3),
#  ('A$AP Rocky', 'Denzel Curry', 3),
#  ('A$AP Rocky', 'Frank Ocean', 3),
#  ('A$AP Rocky', 'Gucci Mane', 3),
#  ('A$AP Rocky', 'James Blake', 3),
#  ('A$AP Rocky', 'Joey Bada$$', 3),
#  ('A$AP Rocky', 'Lil Uzi Vert', 3),
#  ('A$AP Rocky', 'Young Thug', 3),
#  ('A-Trak', 'Armand Van Helden', 3),
#  ('AFROJACK', 'Bebe Rexha', 3),
#  ('AFROJACK', 'French Montana', 3),
#  ('AURORA', 'Pomme', 3),
#  ('Adam Port', 'Malachiii', 3),
#  ('Adam Port', 'Orso', 3),
#  ('Adam Port', 'Stryv', 3),
#  ('Aitch', 'Headie One', 3),
#  ('Akon', 'Dimitri Vegas & Like Mike', 3),
#  ('Alec Benjamin', 'Khalid', 3),
#  ('Alok', 'Armin van Buuren', 3),
#  ('Alok', 'Dimitri Vegas & Like Mike', 3),
#  ('Alok', 'Ella Eyre', 3),
#  ('Alok', 'Never Dull', 3),
#  ('Alok', 'The Chainsmokers', 3),
#  ('Andy Grammer', 'R3HAB', 3),
#  ('Ariana Grande', 'Childish Gambino', 3),
#  ('Ariana Grande', 'Demi Lovato', 3),
#  ('Armin van Buuren', 'Hardwell', 3),
#  ('Armin van Buuren', 'W&W', 3),
#  ('Avicii', 'Rita Ora', 3),
#  ('BTS', 'Charlie Puth', 3),
#  ('BTS', 'Coldplay', 3),
#  ('BTS', 'Jung Kook', 3),
#  ('Bad Bunny', 'Dua Lipa', 3),
#  ('Big Sean', 'Halsey', 3),
#  ('Big Sean', 'Stefflon Don', 3),
#  ('Brandy', 'Monica', 3),
#  ('Britney Spears', 'Elton John', 3),
#  ('Bruno Mars', 'Lady Gaga', 3),
#  ('CamelPhat', 'Anyma', 3),
#  ('Camila Cabello', 'Idina Menzel', 3),
#  ('Camila Cabello', 'Major Lazer', 3),
#  ('Camila Cabello', 'Playboi Carti', 3),
#  ('Charli xcx', 'AFROJACK', 3),
#  ('Charli xcx', 'Bladee', 3),
#  ('Charli xcx', 'French Montana', 3),
#  ('Charli xcx', 'Pabllo Vittar', 3),
#  ('Charli xcx', 'Rita Ora', 3),
#  ('Charli xcx', 'The 1975', 3),
#  ('Charli xcx', 'Tove Lo', 3),
#  ('Coldplay', 'Rihanna', 3),
#  ('Cosculluela', 'Sebastian Yatra', 3),
#  ('D-Block Europe', 'Headie One', 3),
#  ('DJ Khaled', 'Beyoncé', 3),
#  ('DJ Khaled', 'Chance the Rapper', 3),
#  ('DJ Khaled', 'John Legend', 3),
#  ('DJ Khaled', 'Migos', 3),
#  ('DJ Khaled', 'Nicki Minaj', 3),
#  ('DJ Khaled', 'Post Malone', 3),
#  ('DJ Khaled', 'Quavo', 3),
#  ('DaBaby', 'Lil Yachty', 3),
#  ('Daddy Yankee', 'Dimitri Vegas & Like Mike', 3),
#  ('Dalex', 'Justin Quiles', 3),
#  ('Daniel Caesar', 'GIVĒON', 3),
#  ('Danny Ocean', 'LAGOS', 3),
#  ('Dave', 'Headie One', 3),
#  ('David Guetta', 'Anne-Marie', 3),
#  ('David Guetta', 'Charli xcx', 3),
#  ('David Guetta', 'Daddy Yankee', 3),
#  ('David Guetta', 'FAST BOY', 3),
#  ('David Guetta', 'French Montana', 3),
#  ('David Guetta', 'James Carter', 3),
#  ('David Guetta', 'Kim Petras', 3),
#  ('David Guetta', 'NATTI NATASHA', 3),
#  ('David Guetta', 'Nicole Scherzinger', 3),
#  ('David Guetta', 'Sam Martin', 3),
#  ('David Guetta', 'Skylar Grey', 3),
#  ('David Guetta', 'USHER', 3),
#  ('David Kushner', 'Lost Frequencies', 3),
#  ('Dean Lewis', 'Sasha Alex Sloan', 3),
#  ('Descemer Bueno', 'Enrique Iglesias', 3),
#  ('Dido', 'Dimitri Vegas & Like Mike', 3),
#  ('Dido', 'Like Mike', 3),
#  ('Dido', 'W&W', 3),
#  ('Dimitri Vegas', 'Daddy Yankee', 3),
#  ('Dimitri Vegas', 'Dido', 3),
#  ('Dimitri Vegas', 'Nicole Scherzinger', 3),
#  ('Dimitri Vegas', 'W&W', 3),
#  ('Doja Cat', 'Saweetie', 3),
#  ('Dolly Parton', 'Miley Cyrus', 3),
#  ('Don Toliver', 'NAV', 3),
#  ('Dr. Dre', 'Eminem', 3),
#  ('Drake', 'DaBaby', 3),
#  ('Drake', 'French Montana', 3),
#  ('Drake', 'Lil Yachty', 3),
#  ('Dua Lipa', 'PNAU', 3),
#  ('Ellie Goulding', 'Major Lazer', 3),
#  ('Elton John', 'PNAU', 3),
#  ('Farruko', 'Alan Walker', 3),
#  ('Farruko', 'Sabrina Carpenter', 3),
#  ('Fast & Furious: The Fast Saga', 'Jimin', 3),
#  ('Fast & Furious: The Fast Saga', 'Muni Long', 3),
#  ('Felix Jaehn', 'Elley Duhé', 3),
#  ('Flo Rida', 'David Guetta', 3),
#  ('Frank Ocean', 'Tyler, The Creator', 3),
#  ('Future', 'Drake', 3),
#  ('Future', 'JAY-Z', 3),
#  ('Future', 'Lil Yachty', 3),
#  ('Future', 'Rick Ross', 3),
#  ('Future', 'Trippie Redd', 3),
#  ('Future', 'Ty Dolla $ign', 3),
#  ('G-Eazy', 'A$AP Rocky', 3),
#  ('G-Eazy', 'Chris Brown', 3),
#  ('Gabry Ponte', 'Cheat Codes', 3),
#  ('Gotye', 'Kimbra', 3),
#  ('Grey', 'Arcane', 3),
#  ('Grimes', 'Anyma', 3),
#  ('Gucci Mane', 'Lil Baby', 3),
#  ('Gunna', 'Don Toliver', 3),
#  ('Gunna', 'Internet Money', 3),
#  ('Gunna', 'Lil Baby', 3),
#  ('HAYLA', 'Joel Corry', 3),
#  ('Halsey', 'Justin Timberlake', 3),
#  ('Halsey', 'Khalid', 3),
#  ('Halsey', 'Pharrell Williams', 3),
#  ('Halsey', 'benny blanco', 3),
#  ('Hans Zimmer', 'Alan Walker', 3),
#  ('J Balvin', 'Bebe Rexha', 3),
#  ('J Balvin', 'Dua Lipa', 3),
#  ('JVKE', 'Fast & Furious: The Fast Saga', 3),
#  ('JVKE', 'Jimin', 3),
#  ('JVKE', 'Muni Long', 3),
#  ('Jaden Bojsen', 'Sami Brielle', 3),
#  ('James Arthur', 'Lost Frequencies', 3),
#  ('James Arthur', 'Rudimental', 3),
#  ('Jax Jones', 'RAYE', 3),
#  ('Jelly Roll', 'mgk', 3),
#  ('Jessie J', 'Ariana Grande', 3),
#  ('Jessie Reyez', 'Calvin Harris', 3),
#  ('Jimin', 'Muni Long', 3),
#  ('John Martin', 'Martin Garrix', 3),
#  ('John Mayer', 'Zedd', 3),
#  ('Juice WRLD', 'Marshmello', 3),
#  ('Juice WRLD', 'Young Thug', 3),
#  ('Juicy J', 'Ty Dolla $ign', 3),
#  ('Julia Michaels', 'Kygo', 3),
#  ('Julia Michaels', 'Noah Kahan', 3),
#  ('Justin Bieber', 'Boyz II Men', 3),
#  ('Justin Bieber', 'Burna Boy', 3),
#  ('Justin Bieber', 'Chandler Moore', 3),
#  ('Justin Bieber', 'Dan + Shay', 3),
#  ('Justin Bieber', 'Daniel Caesar', 3),
#  ('Justin Bieber', 'Diplo', 3),
#  ('Justin Bieber', 'Dominic Fike', 3),
#  ('Justin Bieber', 'GIVĒON', 3),
#  ('Justin Bieber', 'J Balvin', 3),
#  ('Justin Bieber', 'Khalid', 3),
#  ('Justin Bieber', 'Shawn Mendes', 3),
#  ('Justin Bieber', 'Tori Kelly', 3),
#  ('Justin Timberlake', 'Calvin Harris', 3),
#  ('Kanye West', 'Estelle', 3),
#  ('Kehlani', 'Post Malone', 3),
#  ('Keinemusik', 'Malachiii', 3),
#  ('Keinemusik', 'Orso', 3),
#  ('Keinemusik', 'Stryv', 3),
#  ('Kendrick Lamar', 'Baby Keem', 3),
#  ('Khalid', 'Alina Baraz', 3),
#  ('Khalid', 'Ed Sheeran', 3),
#  ('Kid Cudi', 'A$AP Rocky', 3),
#  ('Kid Cudi', 'Kanye West', 3),
#  ('Kygo', 'Emmit Fenn', 3),
#  ('Kygo', 'Imagine Dragons', 3),
#  ('Kygo', 'Joel Corry', 3),
#  ('Kygo', 'Jonas Brothers', 3),
#  ('Kylie Minogue', 'Diplo', 3),
#  ('LUM!X', 'Prezioso', 3),
#  ('Lady Gaga', 'Ariana Grande', 3),
#  ('Lady Gaga', "Colby O'Donis", 3),
#  ('Lana Del Rey', 'Playboi Carti', 3),
#  ('League of Legends', 'Imagine Dragons', 3),
#  ('Leona Lewis', 'Calum Scott', 3),
#  ('Lil Baby', 'Quality Control', 3),
#  ('Lil Kleine', 'Ronnie Flex', 3),
#  ('Lil Uzi Vert', 'NAV', 3),
#  ('Lil Wayne', 'Kanye West', 3),
#  ('Lil Wayne', 'Tyga', 3),
#  ('Lorde', 'Disclosure', 3),
#  ('Luca-Dante Spadafora', 'Tream', 3),
#  ('Lucas Estrada', 'VINAI', 3),
#  ('Luciano', 'Headie One', 3),
#  ('Luis Fonsi', 'Clean Bandit', 3),
#  ('Luis Fonsi', 'Daddy Yankee', 3),
#  ('Luis Fonsi', 'MARINA', 3),
#  ('M.I.A.', 'Travis Scott', 3),
#  ('M.I.A.', 'Young Thug', 3),
#  ('MORTEN', 'Sia', 3),
#  ('Macklemore', 'Wanz', 3),
#  ('Mako', 'Arcane', 3),
#  ('Mako', 'Grey', 3),
#  ('Mako', 'League of Legends', 3),
#  ('Malachiii', 'Stryv', 3),
#  ('Mariah Carey', 'Ariana Grande', 3),
#  ('Mark Ronson', 'Amy Winehouse', 3),
#  ('Marnik', 'Steve Aoki', 3),
#  ('Martin Garrix', 'Dua Lipa', 3),
#  ('Maverick Sabre', 'Vintage Culture', 3),
#  ('Meek Mill', 'Lil Baby', 3),
#  ('Megan Thee Stallion', 'Cardi B', 3),
#  ('Megan Thee Stallion', 'Lil Baby', 3),
#  ('Megan Thee Stallion', 'Wale', 3),
#  ('Melendi', 'India Martinez', 3),
#  ('Metro Boomin', 'A Boogie Wit da Hoodie', 3),
#  ('Metro Boomin', 'Chris Brown', 3),
#  ('Metro Boomin', 'Coi Leray', 3),
#  ('Metro Boomin', 'Lil Wayne', 3),
#  ('Metro Boomin', 'NAV', 3),
#  ('Metro Boomin', 'Nas', 3),
#  ('Metro Boomin', 'Wizkid', 3),
#  ('Mike WiLL Made-It', 'Swae Lee', 3),
#  ('Miley Cyrus', 'French Montana', 3),
#  ('Morat', 'Aitana', 3),
#  ('Morat', 'Danna Paola', 3),
#  ('NATTI NATASHA', 'Gabry Ponte', 3),
#  ('NATTI NATASHA', 'Sean Paul', 3),
#  ('Naeleck', 'Haley Reinhart', 3),
#  ('Nelly Furtado', 'Timbaland', 3),
#  ('Never Dull', 'Ella Eyre', 3),
#  ('Nicki Minaj', '6ix9ine', 3),
#  ('Nicki Minaj', 'Jessie J', 3),
#  ('Nicki Minaj', 'Rick Ross', 3),
#  ('Nicki Minaj', 'Skylar Grey', 3),
#  ('Nicki Minaj', 'Swae Lee', 3),
#  ('Nicki Minaj', 'The Weeknd', 3),
#  ('Nicky Romero', 'Calvin Harris', 3),
#  ('Niklas Dee', 'Tream', 3),
#  ('Nile Rodgers', 'Oliver Heldens', 3),
#  ('Normani', 'Khalid', 3),
#  ('Offset', 'JID', 3),
#  ('Offset', 'Lil Wayne', 3),
#  ('Offset', 'Lil Yachty', 3),
#  ('Oliver Heldens', 'Calvin Harris', 3),
#  ('OneRepublic', 'Timbaland', 3),
#  ('Orso', 'Malachiii', 3),
#  ('Orso', 'Stryv', 3),
#  ('Ozuna', 'Arcángel', 3),
#  ('Ozuna', 'Wisin', 3),
#  ('P!nk', 'Eminem', 3),
#  ('Pharrell Williams', 'Kendrick Lamar', 3),
#  ('Poppy Baskcomb', 'Anyma', 3),
#  ('Post Malone', 'Lil Baby', 3),
#  ('Post Malone', 'Young Thug', 3),
#  ('Prezioso', 'Gabry Ponte', 3),
#  ('Project Pat', 'Juicy J', 3),
#  ('Quavo', 'Camila Cabello', 3),
#  ('Quavo', 'Chance the Rapper', 3),
#  ('Quavo', 'Lil Uzi Vert', 3),
#  ('Quavo', 'Takeoff', 3),
#  ('Rauw Alejandro', 'Alvaro Diaz', 3),
#  ('Regard', 'RAYE', 3),
#  ('Rick Ross', 'French Montana', 3),
#  ('Rick Ross', 'Jeezy', 3),
#  ('Rick Ross', 'Meek Mill', 3),
#  ('Rihanna', 'Eminem', 3),
#  ('Robin Schulz', 'Lilly Wood and The Prick', 3),
#  ('Robin Schulz', 'Sam Martin', 3),
#  ('Rosa Linn', 'Galantis', 3),
#  ('Rudimental', 'Ed Sheeran', 3),
#  ('SUGA', 'BTS', 3),
#  ('SUGA', 'Halsey', 3),
#  ('Sabrina Carpenter', 'Alan Walker', 3),
#  ('Sam Feldt', 'Kygo', 3),
#  ('Sam Smith', 'Jessie Reyez', 3),
#  ('Sasha Alex Sloan', 'Alan Walker', 3),
#  ('Sean Paul', 'Gabry Ponte', 3),
#  ('Sebastian Yatra', 'Aitana', 3),
#  ('Sebastian Yatra', 'Camilo', 3),
#  ('Sebastian Yatra', 'John Legend', 3),
#  ('Sebastian Yatra', 'Mau y Ricky', 3),
#  ('Sebastian Yatra', 'Nacho', 3),
#  ('Sebastian Yatra', 'Wisin', 3),
#  ('Sebastian Yatra', 'Yandel', 3),
#  ('Selena Gomez', 'A$AP Rocky', 3),
#  ('Selena Gomez', 'DJ Snake', 3),
#  ('Shakira', 'Beyoncé', 3),
#  ('Sia', 'ZAYN', 3),
#  ('Sigala', 'Becky Hill', 3),
#  ('Sigala', 'Gabry Ponte', 3),
#  ('Skepta', 'Wizkid', 3),
#  ('Skylar Grey', 'Eminem', 3),
#  ('Sofiya Nzau', 'Zerb', 3),
#  ('Swae Lee', 'A Boogie Wit da Hoodie', 3),
#  ('Swae Lee', 'Kane Brown', 3),
#  ('Swae Lee', 'Khalid', 3),
#  ('Swae Lee', 'Lil Wayne', 3),
#  ('Swae Lee', 'NAV', 3),
#  ('Swae Lee', 'Offset', 3),
#  ('T-Pain', 'Lil Wayne', 3),
#  ('TOMORROW X TOGETHER', 'Alan Walker', 3),
#  ('Tainy', 'Dua Lipa', 3),
#  ('Tainy', 'Feid', 3),
#  ('Tainy', 'Myke Towers', 3),
#  ('Teddy Swims', 'ILLENIUM', 3),
#  ('That Mexican OT', 'Denzel Curry', 3),
#  ('The Chainsmokers', 'Daya', 3),
#  ('The Lumineers', 'James Bay', 3),
#  ('The Weeknd', 'Bad Bunny', 3),
#  ('The Weeknd', 'French Montana', 3),
#  ('The Weeknd', 'Gesaffelstein', 3),
#  ('The Weeknd', 'Kygo', 3),
#  ('The Weeknd', 'Post Malone', 3),
#  ('Timmy Trumpet', 'Gabry Ponte', 3),
#  ('Tinashe', 'Charli xcx', 3),
#  ('Tiësto', 'Dimitri Vegas & Like Mike', 3),
#  ('Tom Grennan', 'Calvin Harris', 3),
#  ('Tory Lanez', 'Chris Brown', 3),
#  ('Tove Lo', 'Kylie Minogue', 3),
#  ('Travis Scott', '2 Chainz', 3),
#  ('Travis Scott', 'Drake', 3),
#  ('Travis Scott', 'Justin Bieber', 3),
#  ('Travis Scott', 'Kid Cudi', 3),
#  ('Travis Scott', 'Major Lazer', 3),
#  ('Travis Scott', 'Migos', 3),
#  ('Travis Scott', 'Mustard', 3),
#  ('Travis Scott', 'Post Malone', 3),
#  ('Travis Scott', 'SZA', 3),
#  ('Travis Scott', 'Trippie Redd', 3),
#  ('Trey Songz', 'Juicy J', 3),
#  ('Trey Songz', 'Ty Dolla $ign', 3),
#  ('Tungevaag', 'Alan Walker', 3),
#  ('Tungevaag', 'K-391', 3),
#  ('Twenty One Pilots', 'Arcane', 3),
#  ('Tyler, The Creator', 'Steve Lacy', 3),
#  ('Vintage Culture', 'Elderbrook', 3),
#  ('W&W', 'Like Mike', 3),
#  ('W&W', 'R3HAB', 3),
#  ('W&W', 'VINAI', 3),
#  ('WILLOW', 'Travis Barker', 3),
#  ('Wanz', 'Macklemore & Ryan Lewis', 3),
#  ('Wiz Khalifa', 'Miley Cyrus', 3),
#  ('Wiz Khalifa', 'The Weeknd', 3),
#  ('Wizkid', 'Tems', 3),
#  ('X Ambassadors', 'Lost Frequencies', 3),
#  ('YG', 'Mozzy', 3),
#  ('YG', 'Saweetie', 3),
#  ('YNW Melly', 'Juice WRLD', 3),
#  ('YNW Melly', 'Trippie Redd', 3),
#  ('Young Thug', 'Calvin Harris', 3),
#  ('Zedd', 'Grey', 3),
#  ('benny blanco', 'Khalid', 3),
#  ('sped up + slowed', 'Seafret', 3),
#  ('will.i.am', 'Miley Cyrus', 3),
#  ('&ME', 'Black Coffee', 2),
#  ('(G)I-DLE', 'League of Legends', 2),
#  ('070 Shake', 'RAYE', 2),
#  ('2 Chainz', 'Denzel Curry', 2),
#  ('2 Chainz', 'Drake', 2),
#  ('2 Chainz', 'Kanye West', 2),
#  ('2 Chainz', 'Kendrick Lamar', 2),
#  ('2 Chainz', 'Lil Jon', 2),
#  ('2 Chainz', 'Post Malone', 2),
#  ('21 Savage', 'French Montana', 2),
#  ('21 Savage', 'Young Nudy', 2),
#  ('21 Savage', 'Young Thug', 2),
#  ('2WEI', 'Dimitri Vegas & Like Mike', 2),
#  ('50 Cent', 'Ed Sheeran', 2),
#  ('A$AP Ferg', 'Ariana Grande', 2),
#  ('A$AP Ferg', 'French Montana', 2),
#  ('A$AP Ferg', 'Lil Yachty', 2),
#  ('A$AP Rocky', '$NOT', 2),
#  ('A$AP Rocky', 'Blood Orange', 2),
#  ('A$AP Rocky', 'Brent Faiyaz', 2),
#  ('A$AP Rocky', 'Cardi B', 2),
#  ('A$AP Rocky', 'Chief Keef', 2),
#  ('A$AP Rocky', 'Danny Brown', 2),
#  ('A$AP Rocky', 'J. Cole', 2),
#  ('A$AP Rocky', 'Kanye West', 2),
#  ('A$AP Rocky', 'Kendrick Lamar', 2),
#  ('A$AP Rocky', 'Moby', 2),
#  ('A$AP Rocky', 'Takeoff', 2),
#  ('A$AP Rocky', 'The Weeknd', 2),
#  ('A$AP Rocky', 'Yelawolf', 2),
#  ('A7S', 'ATB', 2),
#  ('AJ Tracey', 'D-Block Europe', 2),
#  ('AXMO', 'Lucenzo', 2),
#  ('Abraham Mateo', 'Danny Ocean', 2),
#  ('Aitch', 'D-Block Europe', 2),
#  ('Aitch', 'Ed Sheeran', 2),
#  ('Alesso', 'Katy Perry', 2),
#  ('Alesso', 'OneRepublic', 2),
#  ('Alesso', 'Tove Lo', 2),
#  ('All Time Low', 'Cheat Codes', 2),
#  ('Aloe Blacc', 'Avicii', 2),
#  ('Alok', 'Ava Max', 2),
#  ('Alok', 'Bruno Martini', 2),
#  ('Alok', 'CERES', 2),
#  ('Alok', 'Ellie Goulding', 2),
#  ('Alok', 'James Arthur', 2),
#  ('Alok', 'Joel Corry', 2),
#  ('Alok', 'John Martin', 2),
#  ('Alok', 'KSHMR', 2),
#  ('Alok', 'MC Hariel', 2),
#  ('Alok', 'Mc Davi', 2),
#  ('Alok', 'Sigala', 2),
#  ('Alok', 'Vini Vici', 2),
#  ('Alok', 'Zeeba', 2),
#  ('Alphaville', 'Hypaton', 2),
#  ('Anderson .Paak', 'Anna Kendrick', 2),
#  ('Andrea Bocelli', 'Ed Sheeran', 2),
#  ('Andrea Bocelli', 'Shania Twain', 2),
#  ('Andrea Bocelli', 'Sofia Carson', 2),
#  ('André Rieu', 'Johann Strauss Orchestra', 2),
#  ('Andrés Cepeda', 'Morat', 2),
#  ('Anne-Marie', 'Clean Bandit', 2),
#  ('Anne-Marie', 'James Arthur', 2),
#  ('Anne-Marie', 'Little Mix', 2),
#  ('Anne-Marie', 'Marshmello', 2),
#  ('Anne-Marie', 'Rudimental', 2),
#  ('Anuel AA', '6ix9ine', 2),
#  ('Anuel AA', 'Marshmello', 2),
#  ('Anyma', 'Eric Prydz', 2),
#  ('Anyma', 'RÜFÜS DU SOL', 2),
#  ('Arcane', 'Freya Ridings', 2),
#  ('Arcane', 'Pomme', 2),
#  ('Arcane', 'Royal & the Serpent', 2),
#  ('Arcane', 'Stromae', 2),
#  ('Arcane', 'd4vd', 2),
#  ('Arcángel', 'Randy', 2),
#  ('Argy', 'Anyma', 2),
#  ('Ariana Grande', 'Major Lazer', 2),
#  ('Ariana Grande', 'Monica', 2),
#  ('Ariana Grande', 'Ty Dolla $ign', 2),
#  ('Armin van Buuren', 'Dimitri Vegas & Like Mike', 2),
#  ('Armin van Buuren', 'Goodboys', 2),
#  ('Armin van Buuren', 'Moby', 2),
#  ('Artemas', 'Nessa Barrett', 2),
#  ('Ashnikko', 'Arcane', 2),
#  ('Astrid S', 'Shawn Mendes', 2),
#  ('Ava Max', 'Hypaton', 2),
#  ('Ava Max', 'Lauv', 2),
#  ('Ava Max', 'R3HAB', 2),
#  ('Avicii', 'Bonn', 2),
#  ('Avicii', 'Lenny Kravitz', 2),
#  ('Avicii', 'Nicky Romero', 2),
#  ('Avicii', 'Tiësto', 2),
#  ('Axwell', 'Axwell /\\ Ingrosso', 2),
#  ('Ayra Starr', 'Khalid', 2),
#  ('B.o.B', 'Hayley Williams', 2),
#  ('BUNT.', 'Malachiii', 2),
#  ('Bea Miller', '(G)I-DLE', 2),
#  ('Bea Miller', 'Boyce Avenue', 2),
#  ('Bea Miller', 'League of Legends', 2),
#  ('Bea Miller', 'Zedd', 2),
#  ('Bebe Rexha', 'The Chainsmokers', 2),
#  ('Bebe Rexha', 'Ty Dolla $ign', 2),
#  ('Becky Hill', 'Ella Henderson', 2),
#  ('Benny Benassi', 'Chris Brown', 2),
#  ('Beret', 'Cali Y El Dandee', 2),
#  ('Beret', 'Estopa', 2),
#  ('Beret', 'Lalo Ebratt', 2),
#  ('Beret', 'Lola Indigo', 2),
#  ('Beret', 'Morat', 2),
#  ('Beret', 'Omar Montes', 2),
#  ('Beret', 'Reik', 2),
#  ('Beret', 'Sofía Reyes', 2),
#  ('Beyoncé', 'Eminem', 2),
#  ('Big Sean', '2 Chainz', 2),
#  ('Big Sean', 'Jhené Aiko', 2),
#  ('Big Sean', 'John Legend', 2),
#  ('Big Sean', 'Nicki Minaj', 2),
#  ('Big Sean', 'Ty Dolla $ign', 2),
#  ('Black Eyed Peas', 'Tiësto', 2),
#  ('Bladee', 'Skrillex', 2),
#  ('Blasterjaxx', 'Prezioso', 2),
#  ('Boef', 'Lil Kleine', 2),
#  ('Boef', 'Ronnie Flex', 2),
#  ('Bon Iver', 'Kanye West', 2),
#  ('Brandy', 'Ariana Grande', 2),
#  ('Brent Faiyaz', 'Don Toliver', 2),
#  ('Bring Me The Horizon', 'YUNGBLUD', 2),
#  ('Bruno Mars', 'B.o.B', 2),
#  ('Bruno Martini', 'Zeeba', 2),
#  ('Bryson Tiller', 'Rihanna', 2),
#  ('Busta Rhymes', 'Justin Bieber', 2),
#  ('Busta Rhymes', 'Nate Ruess', 2),
#  ('CERES', 'Gabry Ponte', 2),
#  ('CYRIL', 'Robin Schulz', 2),
#  ('CYRIL', 'Sam Martin', 2),
#  ('Cage The Elephant', 'Beck', 2),
#  ('Cali Y El Dandee', 'Aitana', 2),
#  ('Calum Scott', 'Kungs', 2),
#  ('CamelPhat', 'London Grammar', 2),
#  ('CamelPhat', 'Vintage Culture', 2),
#  ('Camila Cabello', 'Alejandro Sanz', 2),
#  ('Camila Cabello', 'DaBaby', 2),
#  ('Camila Cabello', 'Lil Nas X', 2),
#  ('Camila Cabello', 'Myke Towers', 2),
#  ('Camila Cabello', 'Stromae', 2),
#  ('Camilo', 'Alejandro Sanz', 2),
#  ('Camilo', 'Camila Cabello', 2),
#  ('Camilo', 'Dimitri Vegas & Like Mike', 2),
#  ('Camilo', 'Myke Towers', 2),
#  ('CamrinWatsin', 'Jazzy', 2),
#  ('Cavetown', 'Kina', 2),
#  ('Cavetown', 'beabadoobee', 2),
#  ('Cedric Gervais', 'Joel Corry', 2),
#  ('Chance the Rapper', 'Ed Sheeran', 2),
#  ('Chance the Rapper', 'Lil Wayne', 2),
#  ('Chance the Rapper', 'PnB Rock', 2),
#  ('Charli xcx', 'Addison Rae', 2),
#  ('Charli xcx', 'Ariana Grande', 2),
#  ('Charli xcx', 'Billie Eilish', 2),
#  ('Charli xcx', 'Bon Iver', 2),
#  ('Charli xcx', 'Iggy Azalea', 2),
#  ('Charli xcx', 'Jay Park', 2),
#  ('Charli xcx', 'Joel Corry', 2),
#  ('Charli xcx', 'Kesha', 2),
#  ('Charli xcx', 'Lil Yachty', 2),
#  ('Charli xcx', 'Lizzo', 2),
#  ('Charli xcx', 'Robyn', 2),
#  ('Charli xcx', 'Sam Smith', 2),
#  ('Charli xcx', 'Yung Lean', 2),
#  ('Charlie Puth', 'Muni Long', 2),
#  ('Chris Brown', 'Lil Jon', 2),
#  ('Chris Brown', 'Ty Dolla $ign', 2),
#  ('Ciara', 'Missy Elliott', 2),
#  ('City Girls', 'DaBaby', 2),
#  ('City Girls', 'Latto', 2),
#  ('Cosculluela', 'Cali Y El Dandee', 2),
#  ('D-Block Europe', 'Lil Baby', 2),
#  ('DJ Khaled', 'Cardi B', 2),
#  ('DJ Khaled', 'Chris Brown', 2),
#  ('DJ Khaled', 'DaBaby', 2),
#  ('DJ Khaled', 'Fat Joe', 2),
#  ('DJ Khaled', 'H.E.R.', 2),
#  ('DJ Khaled', 'J. Cole', 2),
#  ('DJ Khaled', 'Megan Thee Stallion', 2),
#  ('DJ Khaled', 'Nas', 2),
#  ('DJ Khaled', 'Rihanna', 2),
#  ('DJ Khaled', 'SZA', 2),
#  ('DJ Snake', 'Lil Jon', 2),
#  ('DaBaby', 'Boosie Badazz', 2),
#  ('DaBaby', 'Roddy Ricch', 2),
#  ('DaBaby', 'Toosii', 2),
#  ('Dalex', 'Dímelo Flow', 2),
#  ('Dalex', 'Farruko', 2),
#  ('Dani Flow', 'Uzielito Mix', 2),
#  ('Daniel Caesar', 'Tyler, The Creator', 2),
#  ('Danny Ocean', 'Greeicy', 2),
#  ('Dave', 'Ed Sheeran', 2),
#  ('David Guetta', 'Avicii', 2),
#  ('David Guetta', 'Becky Hill', 2),
#  ('David Guetta', 'Calvin Harris', 2),
#  ('David Guetta', 'Coi Leray', 2),
#  ('David Guetta', 'D-Block Europe', 2),
#  ('David Guetta', 'Ella Henderson', 2),
#  ('David Guetta', 'Elley Duhé', 2),
#  ('David Guetta', 'Faouzia', 2),
#  ('David Guetta', 'Galantis', 2),
#  ...]

# %%
# Load output from the cell above
result = _ # type: ignore

# Convert the result to a DataFrame
data_frame = result.DataFrame()

# Display the first few rows of the DataFrame
data_frame.head()
# Out:
#        artist_1   artist_2  collaboration_count
# 0  Metro Boomin     Future                   39
# 1         Rampa        &ME                   38
# 2     Adam Port        &ME                   37
# 3         Rampa  Adam Port                   37
# 4    Keinemusik  Adam Port                   33

# %% [markdown]
# # Show tracks
# List the first couple of tracks of the artist pair with the highest collaboration count.

# %%
# Define the specific artist pair
artist_1, artist_2 = data_frame.iloc[0]["artist_1"], data_frame.iloc[0]["artist_2"]

# %%
# %%sql
# SELECT DISTINCT
#   Track.name AS track_name,
#   Track.id AS track_id
# FROM Track
# JOIN TrackArtist ON Track.id = TrackArtist.track_id
# JOIN Artist ON TrackArtist.artist_id = Artist.id
# WHERE Artist.name IN (:artist_1, :artist_2)
#   AND Track.popularity > :track_popularity
#   AND Artist.popularity > :artist_popularity
# Out:
#  * sqlite:///../db/spotify.sqlite
# Done.
# [('All I Know', '0NWqNXBJTpXbkI5rPWNy3p'),
#  ("My Darlin' (feat. Future)", '7hJ1fEr1nf2e4qsE4bfmcc'),
#  ('Cold (feat. Future)', '2NlTOhsAamXOaZciOXbITb'),
#  ('Thrusting (feat. Swae Lee & Future)', '4ZrutH1rzpA4v3Bg9nma55'),
#  ('Turn On The Lights again.. (feat. Future & Fred again..) - Anyma Remix', '4ptnQ0kQnN1U1Ig8TSslj6'),
#  ('Turn On The Lights again.. (feat. Future & Fred again..) - Austin Millz Remix', '1F8hDR8MLN24m2bCWkAWuz'),
#  ('Fine Whine (feat. Joe Fox, Future & M.I.A.)', '2WxzLbJfPA2vJGxQiKd7Jq'),
#  ('On Time (with John Legend)', '0YFqKxV9uNu6LUeYkLOKRS'),
#  ('Superhero (Heroes & Villains) [with Future & Chris Brown]', '0vjeOZ3Ft5jvAi9SBFJm1j'),
#  ('Too Many Nights (feat. Don Toliver & with Future)', '2Hh3ETdQKrmSI3QS0hme7g'),
#  ('Raindrops (Insane) [with Travis Scott]', '1pacwLXyRO47ka0v6LTIiY'),
#  ('Umbrella (with 21 Savage & Young Nudy)', '2Yt4SXIgmoaPZHGdRafp4P'),
#  ('Trance (with Travis Scott & Young Thug)', '5wG3HvLhF6Y5KTGlK0IW3J'),
#  ('Around Me (feat. Don Toliver)', '221qmpQeBNV87sUjQeUTVH'),
#  ('Metro Spider (with Young Thug)', '2VtgzixdB967bHDNu5A1nh'),
#  ("I Can't Save You (Interlude) [with Future & feat. Don Toliver]", '2N9LEu6Pf8nDcp3GjWJT1Z'),
#  ("Creepin' (with The Weeknd & 21 Savage)", '2dHHgzDwk4BJdRwy9uXhTO'),
#  ('Niagara Falls (Foot or 2) [with Travis Scott & 21 Savage]', '4WuOWVnAqvEQxgSRrspBgt'),
#  ("Walk Em Down (Don't Kill Civilians) [with 21 Savage & feat. Mustafa]", '1UsQe17Ef7tV1ahFqHEFR3'),
#  ('Lock On Me (with Travis Scott & Future)', '0OoNzMdPSgbkM5MkcuEZfm'),
#  ('Feel The Fiyaaaah (with A$AP Rocky & feat. Takeoff)', '3SsJ17EnPIu1B4GZshqjIS'),
#  ('All The Money (with Gunna) [Bonus]', '4a1fh9vJMMoRjNrBmEWoM0'),
#  ("We Still Don't Trust You", '7sVbKoBdhXtYCEOO6qC1SN'),
#  ('Drink N Dance', '0SdpzQRdK8BdSV57rn6AZZ'),
#  ('Out Of My Hands', '2BOpFmZQ89Rjm2wvmud1MU'),
#  ('Jealous', '4k8XSN1nCJ0rMf4OKF3zEz'),
#  ('This Sunday', '5pF8pF6U8ZDGTQmTY71hYn'),
#  ('Luv Bad Bitches', '6Gf8Op8esgwchp44p1tIDp'),
#  ('Amazing (Interlude)', '5sOsYuB0SfyKzAeW3BXHjq'),
#  ('All to Myself', '0lOQaZwX9AkAiSvObh4G70'),
#  ('Nights Like This', '6c0rii1TOf2fvq3hhqqExW'),
#  ('Came to the Party', '0ho8zpOysOSWZM9C4jALaV'),
#  ('Right 4 You', '1Aw7MLqN5oqvIva5KWDpGl'),
#  ('Mile High Memories', '20BnS6yXNbYNVgPepicE1W'),
#  ('Overload', '2Cl3OfIwpKJFyJIimbGPCx'),
#  ('Gracious', '3qm3IN6Yx53r3NIououTey'),
#  ('Beat It', '7lsepdNR69a3PS9pWMNICd'),
#  ('Always Be My Fault', '1FIwzmULOKGNmo5bOJqW0P'),
#  ('One Big Family', '40vqMm30NcrokceG9auURz'),
#  ('Red Leather', '4Dx4e0X5dR6TW85dtFU42x'),
#  ('#1 (Intro)', '1oq77Ic0whhb0W7f2a1sh4'),
#  ('Nobody Knows My Struggle', '7nQXU7lu0RhVOSmsa3teKj'),
#  ('All My Life', '6J9ULUfgdVZfWnofbtLkfh'),
#  ('Crossed Out', '3CWXBLm0HSyJQIoTCFM12e'),
#  ('Crazy Clientele', '3GlQVf7QbQv1bro2mPL3K4'),
#  ('Show of Hands', '0cGn4vxyoBftN61XUv2aQk'),
#  ('Streets Made Me A King', '4Orf7Hvci6SZrPIoUjGuFY'),
#  ('Annihilate (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, Lil Wayne, Offset)', '39MK3d3fonIP8Mz9oHCTBB'),
#  ('Am I Dreaming (Metro Boomin & A$AP Rocky, Roisee)', '6Ec5LeRzkisa5KJtwLfOoW'),
#  ('All The Way Live (Spider-Man: Across the Spider-Verse) (Metro Boomin & Future, Lil Uzi Vert)', '0B6g379TMw0nYGXA7y5xHz'),
#  ('Hummingbird (Metro Boomin & James Blake)', '6HexNTb392JS071DoTGo0y'),
#  ('Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, NAV, feat. A Boogie Wit da Hoodie)', '5rurggqwwudn9clMdcchxT'),
#  ('Link Up (Metro Boomin & Don Toliver, Wizkid feat. BEAM & Toian) - Spider-Verse Remix (Spider-Man: Across the Spider-Verse )', '0y8Pu7x5jXgUjOIJvQIF5L'),
#  ('Self Love (Spider-Man: Across the Spider-Verse) (Metro Boomin & Coi Leray)', '0AAMnNeIc6CdnfNU85GwCH'),
#  ('Home (Metro Boomin & Don Toliver, Lil Uzi Vert)', '2qlBAT108lYOzlXhBxBqEv'),
#  ('Nonviolent Communication (Metro Boomin & James Blake, A$AP Rocky, 21 Savage)', '3xMnPIvsaWwzHzqqzaihEX'),
#  ('Nas Morales (Metro Boomin & Nas)', '4mTKCa00WAZS2ag4GYwu0t'),
#  ('Interstate 10 (feat. Future)', '4j13h3sia1FhQG18bjSXEC'),
#  ('All I Know (feat. Future)', '3Xz0rSC29WbaobyJQfeYsp'),
#  ('Flex Up (feat. Future & Playboi Carti)', '5Ryu0SlsYjKh78RkJUONFr'),
#  ('Pardon Me (feat. Future & Mike WiLL Made-It)', '5CLexXIICXEhbRjdKiBLwq'),
#  ('Pardon Me (Lil Yachty feat. Future & Mike WiLL Made-It)', '1sxGIhaxY8eF52e1TlShSP'),
#  ('Peepin Out The Window (with Future & Bslime)', '03kozlqpm5twrblZia0m9j'),
#  ('Annihilate (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, Lil Wayne, Offset)', '0grfvXep0gn5nXdQoHue1a'),
#  ('Am I Dreaming (Metro Boomin & A$AP Rocky, Roisee)', '1hkguHC33aftQObI7mOcoj'),
#  ('All The Way Live (Spider-Man: Across the Spider-Verse) (Metro Boomin & Future, Lil Uzi Vert)', '4z0g4kalqU4vInbOK1B62P'),
#  ('Hummingbird (Metro Boomin & James Blake)', '4EGt2Y8GqjVzjXi39UOQfg'),
#  ('Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, NAV, feat. A Boogie Wit da Hoodie)', '5k3yghc8OMFayi39woODXT'),
#  ('Link Up (Metro Boomin & Don Toliver, Wizkid feat. BEAM & Toian) - Spider-Verse Remix (Spider-Man: Across the Spider-Verse )', '4h1ZtUEwePra4BCLQjLewk'),
#  ('Self Love (Spider-Man: Across the Spider-Verse) (Metro Boomin & Coi Leray)', '2dHNeQOgkDxcheR65nUg7p'),
#  ('Home (Metro Boomin & Don Toliver, Lil Uzi Vert)', '1HB18GDULtgNKWIuutmQXv'),
#  ('Nonviolent Communication (Metro Boomin & James Blake, A$AP Rocky, 21 Savage)', '4WhXZVrBTj3QNRg6A5CGaQ'),
#  ('Nas Morales (Metro Boomin & Nas)', '326WuE8uDVDNitmhTj6qsQ'),
#  ('Annihilate - Spider-Man: Across the Spider-Verse', '6bRXONmpYZQOk8kj54FaRz'),
#  ('Am I Dreaming', '46631VBdAu3LkySeMIHJtd'),
#  ('All The Way Live - Spider-Man: Across the Spider-Verse', '2JHMRT2gvjh6P7ejierydm'),
#  ('Hummingbird', '0J1kF6VdorvmLjmRJObiV1'),
#  ('Calling - Spider-Man: Across the Spider-Verse', '4ltqVxCEyn8xyDDyI4shBm'),
#  ('Link Up - Spider-Verse Remix (Spider-Man: Across the Spider-Verse )', '5jHsuxGiQ4Rtstf7OMYFmy'),
#  ('Self Love - Spider-Man: Across the Spider-Verse', '4D1Lmr5kezw09WYRLbwiZr'),
#  ('Home', '3AAdudm9gOxL6RtJ6lvuKF'),
#  ('Nonviolent Communication', '2IhevZVmRkRSeA2gekFrMM'),
#  ('Nas Morales', '3n230gz4ZeTGPiC5NV5kTB'),
#  ('Annihilate - Spider-Man: Across the Spider-Verse - Instrumental', '0rj3W147rXLe3bokOgWAW9'),
#  ('Am I Dreaming - Instrumental', '4CDFbpbGuat4UXwFvUVePG'),
#  ('Calling - Spider-Man: Across the Spider-Verse - Instrumental', '2Yse8cvkvPOSpUTgY6RzbK'),
#  ('Self Love - Spider-Man: Across the Spider-Verse - Instrumental', '6xq4esa1dAf8ALJM3NAM6M'),
#  ('On Time (with John Legend)', '5TnN3nbB9r37nESkUuHaIR'),
#  ('Superhero (Heroes & Villains) [with Future & Chris Brown]', '1AJuDhb8wqV4gU5Ts6Htl5'),
#  ('Too Many Nights (feat. Don Toliver & with Future)', '36acAPpnxmi4GoeJe1uKdv'),
#  ('Raindrops (Insane) [with Travis Scott]', '1PdhPLXw14jDGaxOmESelp'),
#  ('Umbrella (with 21 Savage & Young Nudy)', '4vJdhRVZMvIbQwbv7o8s5X'),
#  ('Trance (with Travis Scott & Young Thug)', '79hORDzsbz21srcYgJTgMV'),
#  ('Around Me (feat. Don Toliver)', '7BIrLhKtKJcksYlh5FWCgJ'),
#  ('Metro Spider (with Young Thug)', '679nqZvFH0bXeFxcBiYDq5'),
#  ("I Can't Save You (Interlude) [with Future & feat. Don Toliver]", '0jr6KhLkTaVUZA0HlA6FlO'),
#  ("Creepin' (with The Weeknd & 21 Savage)", '4SI5jkfBClYmMWhWWH8f9p'),
#  ('Niagara Falls (Foot or 2) [with Travis Scott & 21 Savage]', '6Xy1JUbm6tgPoF7MbBbP7S'),
#  ("Walk Em Down (Don't Kill Civilians) [with 21 Savage & feat. Mustafa]", '14u4rePYyyd1pJ4XMN5tlq'),
#  ('Lock On Me (with Travis Scott & Future)', '0WAmi1ry8xMt4UjH1t0AdI'),
#  ('Feel The Fiyaaaah (with A$AP Rocky & feat. Takeoff)', '4zGVA7tuYT1W7wkR8Mk5E5'),
#  ('All The Money (with Gunna) [Bonus]', '2eqzCQ9UFr8uL2QNguYnC4'),
#  ('On Time - Instrumental', '26xezUIlpFSaE4su0kCBy9'),
#  ('Superhero (Heroes & Villains) - Instrumental', '2xOBiq7NMvSBqlDQjVvOek'),
#  ('Too Many Nights - Instrumental', '1bPLhob81R6nadD7iHZicd'),
#  ('Trance - Instrumental', '3VXJMNOJvgoqCxi2kFJyLf'),
#  ('Superhero (Heroes & Villains) [with Future & Chris Brown] - ChoppedNotSlopped', '2fBs3IClRp1Gs0EzvlQNYs'),
#  ('Around Me (feat. Don Toliver) - ChoppedNotSlopped', '7eHt2ylQpiTpj7kBk8I3RK'),
#  ('Too Many Nights (feat. Don Toliver & with Future) - ChoppedNotSlopped', '1fnnroMusEsQhsjt0kfohs'),
#  ('Trance (with Travis Scott & Young Thug) - ChoppedNotSlopped', '2Doqhmcb4WoUS0gqRyOaN8'),
#  ('Too Many Nights (feat. Don Toliver & with Future)', '6fjCLTw2qp5913qFQsjgzh'),
#  ('Trance (with Travis Scott & Young Thug)', '5KhuQ56d91AIfY52S2PcU3'),
#  ("Creepin' (with The Weeknd & 21 Savage)", '162gREXZWRD3TWrbiy68PA'),
#  ('DnF (feat. Drake & Future)', '5EMKS6mLi4JprJxy8IGdhT'),
#  ('New Level REMIX (feat. Future, A$AP Rocky & Lil Uzi Vert)', '36evXa8bNvfBYNzePEWhG1'),
#  ('U.O.E.N.O.', '1baooPNpHuiV81mVg5yjVO'),
#  ('How Many Times (feat. Future)', '4oOzx2fEmOpPWb9LK2ReX0'),
#  ('Enjoy The Show (feat. Future)', '637oNhilCI9UlkWkUW4Grt'),
#  ('Die For Me (feat. Future & Halsey)', '2C6WXnmZ66tHhHlnvwePiK'),
#  ('Double Fantasy (with Future)', '2WxcXtp6kuC7biYBxBbeeG'),
#  ('Double Fantasy (with Future)', '4VMRsbfZzd3SfQtaJ1Wpwi'),
#  ('Double Fantasy (with Future) - Radio Edit', '0vuiKizDyUXdIge9npkEKn'),
#  ("Creepin' (feat. 21 Savage) - Remix", '5Ee4IyhPaOVRMc15fUOeG9'),
#  ("Creepin'", '1Tr5FhvxC4IlRXYJHCXJdZ'),
#  ('Buckets (feat. Future) - From SR3MM', '2TtWdYXulGcHCeUJUWwZ4M'),
#  ('Amazing (feat. Future)', '4xyhmhurbsNC0cYaAgAxt1'),
#  ('Sir (feat. Future)', '6aP5nH2SNEQzf4EXA6bjAh'),
#  ('Sir (feat. Future)', '6DvJX7wAAzRomZJVW7E9dQ'),
#  ("Creepin' (Remix)", '0SxPUlxFrNHG03ELIRaApe'),
#  ('Drinks On Us', '3Z4iF2sFcW63WclmUYd7IE'),
#  ("What's Hatnin'", '1p5M91qghUkzS4gwuMM22B'),
#  ('Private Landing (feat. Justin Bieber & Future)', '4EDTT4kSqfpc0FKuxfNo2E'),
#  ('Private Landing (feat. Justin Bieber & Future)', '2Ryzn1QqRKIKbAMNEXbLSB'),
#  ('3500 (feat. Future & 2 Chainz)', '1SGt65i9AnXYdDQt1AtDRH'),
#  ('Private Landing (feat. Justin Bieber & Future)', '52NGJPcLUzQq5w7uv4e5gf'),
#  ('Picasso (feat. Future)', '2kPlWEOm2tQlaZRE01IbBQ'),
#  ('Smoke Break (feat. Future)', '1Uq3IOIy1CUlHUgP6vWpum'),
#  ("I Can't Even Lie (feat. Future & Nicki Minaj)", '5xQUK12259s4pQi17Fw021'),
#  ('Down for Life (feat. PARTYNEXTDOOR, Future, Travis Scott, Rick Ross & Kodak Black)', '1YsFOm6hFKqSLgu9RTpQB8'),
#  ('Iced Out My Arms (feat. Future, Migos, 21 Savage & T.I.)', '0Sya8tcvqVXsn1u96NEu2V'),
#  ('Top Off (feat. JAY Z, Future & Beyoncé)', '0QzliuYF4qRMXI76GwepXq'),
#  ('Private Landing (Sped Up) [feat. Justin Bieber & Future]', '0Ntea3SB1jJ0SxRNt5MvjM'),
#  ('Private Landing (feat. Justin Bieber & Future)', '6nXVu6bvDi1qYWmlFKnyq7'),
#  ('Hear No Evil (feat. Future)', '3dDdYVWY1wWlcpKoZZLyMy'),
#  ('Everyday', '30TmLgK0ja5O8q9l4BShIX'),
#  ('Unicorn Purp (feat. Young Thug & Gunna)', '2U3LJfQB0ALLxC7Yy0QW7l'),
#  ('Jumpin on a Jet', '1I3ZAmPmbFV78oNKnibOiW'),
#  ('First Off (feat. Travis Scott)', '3WRIaWsws011vHMd9uzPjG'),
#  ('Temptation', '2gXOzCwbVXACCaYRj4Qrep'),
#  ('Mile High (feat. Travis Scott & Metro Boomin)', '6gWo0JYLA6Dnw40WIx1MTl'),
#  ('So Good (& Metro Boomin)', '0fWBFDRTIuk8ZgNdZqhCer'),
#  ('KEEP IT BURNIN (feat. Kanye West)', '4Ew8VKrbgrjCt9r2AuItFm'),
#  ('Lie to Me', '4O0qHBvIV8yHOcPkGJUUIZ'),
#  ('FULLY LOADED', '1appK6Io3nO3sSAMi2POQd'),
#  ('Cold - Remix', '0ihh3AvTzYmgZ1nY1Thb7G'),
#  ('That’s It', '5LT018mJrqHdNwdltZ1hAM'),
#  ('LIL DEMON', '5UwhSyAaU6b5RHeYPzxZld'),
#  ('BRAZZIER', '7HoaYINSi0cdzihasNhxwi'),
#  ('SOUTH OF FRANCE - REMIX', '2C11qhXSCvVzGogwOTP6aZ'),
#  ('RECIPE FOR LOVE (feat. Future)', '0zmPHHsyuaVfw3YphpRG44'),
#  ('READY TO COOK UP', '75rNNskDNJJz45znMDaMnV'),
#  ('Warm Words in a Cold World (feat. Wale & Future)', '7MXMsxYGTcU0tD54EnBL9f'),
#  ('Keep Quiet', '1j703cUWGLGtl3n41HI3Hx'),
#  ('Kid That Didd (feat. Future & Doe Boy)', '4zwSuVPORpri4LYy50J3J7'),
#  ('AYE SAY GANG', '4O6NSgl6k5qH43eGUKoLng'),
#  ('TRY & SEE (feat. Future, G Herbo & Roddy Ricch)', '7D0RCMzX66F9TIr9XB66kh'),
#  ('Same Damn Time', '0evYh0thMGFGri2roKou3I'),
#  ('TELEKINESIS (feat. SZA & Future)', '1i9lZvlaDdWDPyXEE95aiq'),
#  ('Faceshot', '5R2pz8i4k4bvRAqiIFXzKz'),
#  ('Overdose', '5OUHuypXfqeKaHNO44ojio'),
#  ("Don't Judge Me (feat. Future & Swae Lee)", '2EPbvVyo2qrrmeiEm57Cfl'),
#  ('TEFLON DON', '2aGF1a9126wvzwrK01DLff'),
#  ('Real and True (feat. Mr Hudson)', '5TxsupFF2Vc70TQdLyyOE3'),
#  ('Pressurelicious (feat. Future)', '16knHihZqSUCl07ablNPPl'),
#  ('BEAUTIFUL (feat. Future & SZA)', '5kYSScXYOZYyi0fxramiW6'),
#  ('Blue Pill', '3VFI494i8DoYzkA5boYxCw'),
#  ('Lookin Exotic', '6Mz7ULRwNSCOdut6M3tNs2'),
#  ('OCEAN', '0K4VRE5GQXvMWviP3PG0E8'),
#  ('AFFILIATED (feat. Lil Durk)', '7wqTOAyaUd6nSxo8rxhDdk'),
#  ('Turn On The Lights', '6mavtNxMc35XwKg9POUemZ'),
#  ('MJ', '2dK0FAkNYCMCB5Rv5LZsHL'),
#  ('Off Dat', '5MxBxefjpl4hmbxgdfse8x'),
#  ('Teen X (feat. Future)', '5uYqmEN6TAAE8ss8YmprNV'),
#  ('I Got the Keys (feat. JAY-Z & Future)', '6X92l986jasw5nvGsblwk0'),
#  ('Rollin (feat. Future & Khalid)', '3FDrI0FLKzrYQiWxPhqV2W'),
#  ('FRANCHISE (feat. Future, Young Thug & M.I.A.) - REMIX', '6qUabsNxudatEFedWGHoDh'),
#  ('LIKE ME (feat. 42 Dugg & Lil Baby)', '3gOL6mYIq19Oq8raxIntrV'),
#  ('Benz Friendz (Whatchutola) (feat. André 3000)', '4E7H6rqgxHdSoeGSS28CTY'),
#  ('Top Off (feat. JAY Z, Future & Beyoncé)', '1W6wxOOYyJyyok8fqYSZ3m'),
#  ('New Illuminati', '0qH1jbTUbpCxZE7AMkjApD'),
#  ('My Collection', '0526DaOuV7mRlPKxhMSJKw'),
#  ('Savage Time (& Metro Boomin)', '6Vur2D5ks3pdAZqqmLIeab'),
#  ('GOLD STACKS', '3dOlp9jd5eM4aIrGt37Otu'),
#  ('Tony Montana (feat. Drake)', '4hjloKONMQyJHOmSzAwuAq'),
#  ('Blood, Sweat, Tears', '4EpDZxSApKaod3PVqT5ben'),
#  ('MASSAGING ME', '5hs2urSRIvZbmcQwvxEtat'),
#  ('Loveeeeeee Song', '3Ij4WlSogXNafuyz6V2Xvl'),
#  ('SOUTH OF FRANCE', '4o7drGxPLryZ8AQ3wChg54'),
#  ('Incredible', '2qwn6whaZf7gax7SaqUZSC'),
#  ('Program', '5lMmp06Yt5opZrKdszyh8Y'),
#  ('Karate Chop (Remix) (feat. Lil Wayne)', '2Ih0U9yUuY0oU2In3h21If'),
#  ('PSYCHO', '0VnPlYSJBh7t1LfOIMvM0d'),
#  ('Xanny Family', '0BzDQgmeRdA4V71VhfBvXT'),
#  ('No Hearts, No Love (& Metro Boomin)', '6LotTSj4ATgXgke2ktLC1O'),
#  ('Rocket Ship', '4HfaOznGhHYWqPtpLYz2PB'),
#  ('End Game', '2x0WlnmfG39ZuDmstl9xfX'),
#  ('Sup Mate (feat. Future)', '0F7uqQx9trviYhGwD0GD9B'),
#  ('LIGHTSKIN SH*T (feat. Future & jetsonmade)', '16oi4OiKmkO51l60F5R9kR'),
#  ('Mask Off - Marshmello Remix', '5rK0pyEObO4DBFLy682QvR'),
#  ('THE WAY THINGS GOING', '4TWTigoUK4bhag1N13CIxx'),
#  ("I'M DAT N****", '7IDJ19VgYwZSzDH5Ku5FT9'),
#  ('CHICKENS (feat. EST Gee)', '15B3zlNGr8fYj60exaIPkl'),
#  ("Ain't No Time", '7givkGZW1cwM8MJYzMd2Na'),
#  ('Talk Shit Like a Preacher', '2aR4gdgyCgacqHGqUZ91YS'),
#  ('My Business (feat. Future)', '2AEtYwT9qg2eY6G9m8wOxW'),
#  ('Bankroll', '2LyYvjkKkchY8JXKu6m5Ri'),
#  ('Heart In Pieces', '669gYFBhezfYPXQP1hBMOX'),
#  ('Stuck Together (feat. Lil Baby & Future)', '2MPn5aXEKrRBP5hv8s0HVc'),
#  ('TOLD MY', '73HVP0b4K6iemnDBX22pqC'),
#  ('Seven Rings', '2O0PpdgMmzBj2ZY8cqjfpO'),
#  ('Tricks on Me', '2HEsewd9dzzLg4751JIS4p'),
#  ('Rockstar Chainz', '1WFkr1TlmOQEgrLndQI6sY'),
#  ('In Tune (& Metro Boomin)', '5bq7cr4wjs9LaK7V7onc5F'),
#  ('Look Ahead', '2W10vndZ7uSOKVineVfjOa'),
#  ('Bought A Bad Bitch', '0NfbJvgf9mmdnoyzxNf46H'),
#  ('Baptiize', '01sjbEk3X7KNXFvXXXN5MY'),
#  ('LOST MY DOG', '1cGABOlfqiaXwb3SzukpJ5'),
#  ('Reason (& Metro Boomin)', '4GvhvCrqxhpyMBUzwdDC0T'),
#  ('Life Is Good (feat. Drake)', '5yY9lUy8nbvjM1Uyo1Uqoc'),
#  ('Stripes Like Burberry', '68ra53eElfqZM8G9fuOFSj'),
#  ('PIE (feat. Chris Brown)', '5FsJ8AUxW1KBypdhFvbdkd'),
#  ('F&N', '5YP6yKgGGsXKukqxXypVAf'),
#  ('Honest', '5ik5nMy8vdS2rXe7SAGt2K'),
#  ('Baby Sasuke', '4Y4Xmm8OLUJSdR9OkaxV97'),
#  ('Cars Bring Me Out (feat. Future)', '2Okh2n1EHlGhviAYv75MOB'),
#  ('Patek', '3f9RZbFJrmttvXYwiwqDlb'),
#  ('My Legacy', '4V9K7DLPZNhCH77wLsAiNF'),
#  ('Neva Missa Lost', '4Q40ZOINE8zsLJE3pWIqix'),
#  ('Solo', '4lH6nENd1y81jp7Yt9lTBX'),
#  ('Million Dollar Play', '3kAyhdS74oZn8nOqifDEf2'),
#  ('Mad Max', '2i2qDe3dnTl6maUE31FO7c'),
#  ('Wassup (feat. Future)', '19Ec2gbNtQTE44IizcPjtD'),
#  ('Campaign (feat. Future)', '6JvHYmanlC8FdbeiCztcrR'),
#  ('March Madness', '3WcC6NH9J77xPEvj1SOL7z'),
#  ('Do You Mind (feat. Nicki Minaj, Chris Brown, August Alsina, Jeremih, Future & Rick Ross)', '6ezg5Mm5UEEi3Oqsbb7Cjn'),
#  ('Allure (feat. Future & Mike WiLL Made-It)', '0a7l3wF74g1arXvKU42VYs'),
#  ('Photo Copied', '4Fi7fihVNkHPfBZ7KeSXVH'),
#  ('Same Damn Time (Remix) (feat. Diddy & Ludacris)', '7BbbLiARcvEIhyMCcTRfJr'),
#  ('No Basic', '2OUlIVy6bF8VQAdw4rWfsN'),
#  ('Rap Saved Me (feat. Quavo)', '0tdCy39PgWN8LFWu34ORn3'),
#  ('She Never Been To Pluto', '50lt8PNUgIYnIrr3BPp2Cv')]

# %%
# Load the output from the cell above
result = _ # type: ignore

# Execute the query and load the data into a DataFrame
top_tracks_df = result.DataFrame()

# Display the top tracks
top_tracks_df.head()
# Out:
#                                           track_name                track_id
# 0                                         All I Know  0NWqNXBJTpXbkI5rPWNy3p
# 1                          My Darlin' (feat. Future)  7hJ1fEr1nf2e4qsE4bfmcc
# 2                                Cold (feat. Future)  2NlTOhsAamXOaZciOXbITb
# 3                Thrusting (feat. Swae Lee & Future)  4ZrutH1rzpA4v3Bg9nma55
# 4  Turn On The Lights again.. (feat. Future & Fre...  4ptnQ0kQnN1U1Ig8TSslj6

# %% [markdown]
# # Create Collaboration Graph
# Create a NetworkX graph from the DataFrame, filtering edges based on a minimum number of collaborations.

# %%
# Create NetworkX graph from the DataFrame, filtering edges based on a minimum number of collaborations
def create_graph(data_frame: pd.DataFrame, min_collaborations: int = 3) -> nx.Graph:
    G = nx.Graph()
    
    # Use itertuples() for better performance
    for row in data_frame.itertuples(index=False):
        G.add_edge(row.artist_1, row.artist_2, weight=row.collaboration_count)

    # Filter low-weight edges
    filtered_edges = [(u, v) for u, v, d in G.edges(data=True) if d["weight"] > min_collaborations]
    return G.edge_subgraph(filtered_edges).copy()

# Create graph with a minimum collaboration threshold
G_filtered = create_graph(data_frame, min_collaborations=4)
print(f"Nodes: {G_filtered.number_of_nodes()}, Edges: {G_filtered.number_of_edges()}")
# Out:
# Nodes: 244, Edges: 273

# %% [markdown]
# # Calculate Centrality Measures
# Calculate degree centrality and betweenness centrality for the nodes in the graph.

# %%
# Sets centrality values to 1 for max to 0 for min
def normalize_centrality(centrality_dict):
    values = list(centrality_dict.values())
    scaler = MinMaxScaler()
    normalized_values = scaler.fit_transform([[v] for v in values]).flatten()
    
    return dict(zip(centrality_dict.keys(), normalized_values))

# Degree and betweenness centrality
degree_centrality = normalize_centrality(nx.degree_centrality(G_filtered))
betweenness_centrality = normalize_centrality(nx.betweenness_centrality(G_filtered))

# Display top 5 artists
print("\n🎵 Top 5 Artists by Degree Centrality:")
for artist, score in sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:5]:
    print(f"{artist}: {score:.3f}")

print("\n🔗 Top 5 Artists by Betweenness Centrality:")
for artist, score in sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)[:5]:
    print(f"{artist}: {score:.3f}")
# Out:
# 🎵 Top 5 Artists by Degree Centrality:
# David Guetta: 1.000
# The Weeknd: 1.000
# Justin Bieber: 1.000
# Metro Boomin: 0.833
# Travis Scott: 0.750
#
# 🔗 Top 5 Artists by Betweenness Centrality:
# David Guetta: 1.000
# The Weeknd: 0.641
# Nicki Minaj: 0.621
# Justin Bieber: 0.571
# Kygo: 0.463

# %% [markdown]
# # Detect Communities
# Use the Louvain method to detect communities within the graph and print the number of detected communities.

# %%
# Use the Louvain method to detect communities within the graph
partition = community_louvain.best_partition(G_filtered)

# Print the number of detected communities
num_communities = len(set(partition.values()))
print(f"Detected {num_communities} artist communities.")
# Out:
# Detected 53 artist communities.

# %% [markdown]
# # Visualize Collaboration Network
# Each dot represents an artist. Each line represents a relation, thicker lines represent more collaborations between the artists.

# %%
# Create a Pyvis network visualization
def visualize_graph_pyvis(G: nx.Graph):
    net = Network(notebook=True, width="100%", height="700px", bgcolor="#222222", font_color="white")
    
    for node in G.nodes():
        net.add_node(node, title=node, color="blue")
    
    for edge in G.edges(data=True):
        net.add_edge(edge[0], edge[1], value=edge[2].get('weight', 1))

    net.toggle_physics(True)  # Enable physics for better layout
    
    net.set_options("""
        var options = {
          "nodes": { "shape": "dot", "size": 10 },
          "edges": { "color": "gray", "width": 1 },
          "physics": {
            "barnesHut": { "gravitationalConstant": -30000, "centralGravity": 0.3 }
          }
        }
    """)
    
    net.show("artist_network.html")

visualize_graph_pyvis(G_filtered)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# artist_network.html
